# %%
from rdflib import Graph, URIRef, Namespace, Literal, XSD, RDF
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from tqdm.autonotebook import tqdm
import pandas as pd
from copy import deepcopy
import numpy
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import defaultdict
from rapidfuzz import process, fuzz, distance

import torch
from transformers import BertTokenizer
from transformers import BertModel
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /var/folders/6f/k2t20zbs4db5khp6mgdq_06m0000gn/T/ipykernel_70408/3626711984.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
GRAPH_1_INV_FUNC_PATH = ''
GRAPH_1 = ""
GRAPH_2_INV_FUNC_PATH = ''
GRAPH_2 = ""
#GRAPH_2 = "http://localhost:9999/bigdata/sparql"
SUBJECT = 'subject'
PREDICATE = 'predicate'
INVERSE_FUNCTIONALITY = 'inverse_functionality'

# %%
graph_1_inv_func_df = pd.read_csv(GRAPH_1_INV_FUNC_PATH)

threshold_graph_1_inv_func_df = graph_1_inv_func_df[graph_1_inv_func_df[INVERSE_FUNCTIONALITY] > 0.5]

#graph_1_predicate_list = threshold_graph_1_inv_func_df[PREDICATE].tolist()

graph_1 = Graph()
graph_1.parse(GRAPH_1)
# Out:
# <Graph identifier=Ne66a7f22697e4cbeb53ef1fef7dc3798 (<class 'rdflib.graph.Graph'>)>

# %%
graph_2_inv_func_df = pd.read_csv(GRAPH_2_INV_FUNC_PATH)

threshold_graph_2_inv_func_df = graph_2_inv_func_df[graph_2_inv_func_df[INVERSE_FUNCTIONALITY] > 0.5]

#graph_2_predicate_list = threshold_graph_2_inv_func_df[PREDICATE].tolist()

graph_2 = Graph()
graph_2.parse(GRAPH_2)
#graph_2 = Graph("SPARQLStore")
#graph_2.open(GRAPH_2)
# Out:
# <Graph identifier=N039f8d41798747f69abc438b7b0c6828 (<class 'rdflib.graph.Graph'>)>

# %%
def get_label_graph(graph, predicate_df):
    predicate_label_list = list()
    LABEL = "http://www.w3.org/2000/01/rdf-schema#label"
    label_predicate = URIRef(LABEL)
    for index, row in tqdm(predicate_df.iterrows(), total=len(predicate_df)):
        search_uriref = URIRef(row['predicate'])
        label = str(next(graph.objects(search_uriref, label_predicate), ""))
        predicate_label_list.append(label)
    return predicate_label_list

# %%
predicate_1_list = get_label_graph(graph_1, graph_1_inv_func_df)
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]

# %%
graph_1_inv_func_df['labels'] = predicate_1_list

# %%
graph_1_inv_func_df
# Out:
#      Unnamed: 0                                          predicate  \
# 0             0  http://dbkwik.webdatacommons.org/ontology/wiki...
# 1             1    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2             2                   http://purl.org/dc/terms/subject
# 3             3  http://dbkwik.webdatacommons.org/ontology/wiki...
# 4             4                http://xmlns.com/foaf/0.1/thumbnail
# ..          ...                                                ...
# 337         337  http://dbkwik.webdatacommons.org/memory-alpha....
# 338         338  http://dbkwik.webdatacommons.org/memory-alpha....
# 339         339  http://dbkwik.webdatacommons.org/memory-alpha....
# 340         340  http://dbkwik.webdatacommons.org/memory-alpha....
# 341         341  http://dbkwik.webdatacommons.org/memory-alpha....
#
#      inverse_functionality           labels
# 0                 0.064058
# 1                 0.001296
# 2                 0.022274
# 3                 0.978144
# 4                 1.000000
# ..                     ...              ...
# 337               1.000000        Packs/Box
# 338               1.000000
# 339               1.000000  nArc3PartNumber
# 340               1.000000          Written
# 341               1.000000          website
#
# [342 rows x 4 columns]

# %%
predicate_2_list = get_label_graph(graph_2, graph_2_inv_func_df)
# Out:
#   0%|          | 0/218 [00:00<?, ?it/s]

# %%
graph_2_inv_func_df['labels'] = predicate_2_list

# %%
graph_2_inv_func_df
# Out:
#      Unnamed: 0                                          predicate  \
# 0             0             http://purl.org/dc/elements/1.1/rights
# 1             1  http://dbkwik.webdatacommons.org/ontology/wiki...
# 2             2       http://www.w3.org/2000/01/rdf-schema#comment
# 3             3       http://www.w3.org/2004/02/skos/core#altLabel
# 4             4  http://dbkwik.webdatacommons.org/ontology/thum...
# ..          ...                                                ...
# 213         213  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 214         214  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 215         215  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 216         216  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 217         217  http://dbkwik.webdatacommons.org/stexpanded.wi...
#
#      inverse_functionality        labels
# 0                 0.500000
# 1                 0.123107
# 2                 0.999063
# 3                 1.000000
# 4                 0.288348
# ..                     ...           ...
# 213               1.000000          skin
# 214               1.000000      assigned
# 215               1.000000             y
# 216               1.000000      duration
# 217               1.000000  Original Run
#
# [218 rows x 4 columns]

# %%
graph_1_predicate_set = set(graph_1_inv_func_df['predicate'])

# %%
graph_2_predicate_set = set(graph_2_inv_func_df['predicate'])

# %%
predicate_prob_dict = dict()

# %%
for predicate_uri in graph_1_predicate_set:
    if predicate_uri in graph_2_predicate_set:
        if not predicate_uri in predicate_prob_dict.keys():
            predicate_prob_dict[predicate_uri] = dict()
        predicate_prob_dict[predicate_uri][predicate_uri] = 1.0

# %%
graph_2_predicate_labels_dict = {label: list(graph_2_inv_func_df.loc[graph_2_inv_func_df['labels'] == label, 'predicate'])
           for label in graph_2_inv_func_df['labels'].unique()}

# %%
del graph_2_predicate_labels_dict['']

# %%
for _, row in graph_1_inv_func_df.iterrows():
    label = row['labels']
    predicate_1 = row['predicate']
    if label in graph_2_predicate_labels_dict:
        for predicate_2 in graph_2_predicate_labels_dict[label]:
            if predicate_1 in predicate_prob_dict.keys() and predicate_2 in predicate_prob_dict[predicate_1].keys():
                continue
            predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = 0.9

# %%
def normalize_string(s):
    # remove punctuation
    s = s.translate(str.maketrans('', '', string.punctuation))
    # split the string at uppercase letters and digits and join with spaces
    s = re.sub(r'([a-z])([A-Z])', r'\1 \2', s)
    s = re.sub(r'([A-Z])([A-Z][a-z])', r'\1 \2', s)
    s = re.sub(r'([a-zA-Z])(\d)', r'\1 \2', s)
    s = re.sub(r'(\d)([a-zA-Z])', r'\1 \2', s)
    # replace underscores with spaces
    s = s.replace('_', ' ')
    # remove multiple consecutive spaces and leading/trailing spaces
    s = ' '.join(s.split()).strip()
    # convert to lowercase and return
    return s.lower()

# %%
graph_1_inv_func_df['normalized label'] = graph_1_inv_func_df['labels'].apply(normalize_string)

# %%
graph_2_inv_func_df['normalized label'] = graph_2_inv_func_df['labels'].apply(normalize_string)

# %%
graph_2_inv_func_df
# Out:
#      Unnamed: 0                                          predicate  \
# 0             0             http://purl.org/dc/elements/1.1/rights
# 1             1  http://dbkwik.webdatacommons.org/ontology/wiki...
# 2             2       http://www.w3.org/2000/01/rdf-schema#comment
# 3             3       http://www.w3.org/2004/02/skos/core#altLabel
# 4             4  http://dbkwik.webdatacommons.org/ontology/thum...
# ..          ...                                                ...
# 213         213  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 214         214  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 215         215  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 216         216  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 217         217  http://dbkwik.webdatacommons.org/stexpanded.wi...
#
#      inverse_functionality        labels normalized label
# 0                 0.500000
# 1                 0.123107
# 2                 0.999063
# 3                 1.000000
# 4                 0.288348
# ..                     ...           ...              ...
# 213               1.000000          skin             skin
# 214               1.000000      assigned         assigned
# 215               1.000000             y                y
# 216               1.000000      duration         duration
# 217               1.000000  Original Run     original run
#
# [218 rows x 5 columns]

# %%
LABEL = 'normalized label'

graph_2_predicate_labels_dict = {label: list(graph_2_inv_func_df.loc[graph_2_inv_func_df[LABEL] == label, 'predicate'])
           for label in graph_2_inv_func_df[LABEL].unique()}
del graph_2_predicate_labels_dict['']

for _, row in graph_1_inv_func_df.iterrows():
    label = row[LABEL]
    predicate_1 = row['predicate']
    if label in graph_2_predicate_labels_dict:
        for predicate_2 in graph_2_predicate_labels_dict[label]:
            if predicate_1 in predicate_prob_dict.keys() and predicate_2 in predicate_prob_dict[predicate_1].keys():
                continue
            predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = 0.8

# %%
nltk.download('stopwords') # download stop words list

stop_words = set(stopwords.words('english')) # set of English stop words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yamamotobikutorueiichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(s):
    words = s.split() # split text into individual words

    filtered_words = [word for word in words if not word.lower() in stop_words] # remove stop words

    filtered_text = ' '.join(filtered_words)
    return filtered_text

# %%
graph_1_inv_func_df['stopword label'] = graph_1_inv_func_df['normalized label'].apply(remove_stopwords)

# %%
graph_2_inv_func_df['stopword label'] = graph_2_inv_func_df['normalized label'].apply(remove_stopwords)

# %%
graph_2_inv_func_df
# Out:
#      Unnamed: 0                                          predicate  \
# 0             0             http://purl.org/dc/elements/1.1/rights
# 1             1  http://dbkwik.webdatacommons.org/ontology/wiki...
# 2             2       http://www.w3.org/2000/01/rdf-schema#comment
# 3             3       http://www.w3.org/2004/02/skos/core#altLabel
# 4             4  http://dbkwik.webdatacommons.org/ontology/thum...
# ..          ...                                                ...
# 213         213  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 214         214  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 215         215  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 216         216  http://dbkwik.webdatacommons.org/stexpanded.wi...
# 217         217  http://dbkwik.webdatacommons.org/stexpanded.wi...
#
#      inverse_functionality        labels normalized label stopword label
# 0                 0.500000
# 1                 0.123107
# 2                 0.999063
# 3                 1.000000
# 4                 0.288348
# ..                     ...           ...              ...            ...
# 213               1.000000          skin             skin           skin
# 214               1.000000      assigned         assigned       assigned
# 215               1.000000             y                y
# 216               1.000000      duration         duration       duration
# 217               1.000000  Original Run     original run   original run
#
# [218 rows x 6 columns]

# %%
LABEL = 'stopword label'

graph_2_predicate_labels_dict = {label: list(graph_2_inv_func_df.loc[graph_2_inv_func_df[LABEL] == label, 'predicate'])
           for label in graph_2_inv_func_df[LABEL].unique()}
del graph_2_predicate_labels_dict['']

for _, row in graph_1_inv_func_df.iterrows():
    label = row[LABEL]
    predicate_1 = row['predicate']
    if label in graph_2_predicate_labels_dict:
        for predicate_2 in graph_2_predicate_labels_dict[label]:
            if predicate_1 in predicate_prob_dict.keys() and predicate_2 in predicate_prob_dict[predicate_1].keys():
                continue
            predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = 0.7

# %%
def remove_corpus_specific_stopword(graph_df):
    doc_freq = defaultdict(int)

    for _, row in graph_df.iterrows():
        doc = row['stopword label']
        words = set(word_tokenize(doc))
        for word in words:
            doc_freq[word] += 1
            
    total_docs = len(graph_df)
    corpus_stopwords = set()
    for word, freq in doc_freq.items():
        if freq / total_docs > 0.2: # word appears in more than 20% of documents
            corpus_stopwords.add(word)
    print(corpus_stopwords)
    
    label_list = list()
    for _, row in graph_df.iterrows():
        words = word_tokenize(row['stopword label'])
        filtered_words = [word for word in words if not word.lower() in corpus_stopwords]
        filtered_text = ' '.join(filtered_words)
        label_list.append(filtered_text)
    
    graph_df['corpus stopword label'] = label_list

# %%
remove_corpus_specific_stopword(graph_1_inv_func_df)
# Out:
# set()

# %%
remove_corpus_specific_stopword(graph_2_inv_func_df)
# Out:
# set()

# %%
LABEL = 'corpus stopword label'

for _, row in graph_1_inv_func_df.iterrows():
    label_1 = row[LABEL]
    predicate_1 = row['predicate']
    if not label_1:
        continue
    
    for _, row_2 in graph_2_inv_func_df.iterrows():
        label_2 = row_2[LABEL]
        predicate_2 = row_2['predicate']
        if not label_2:
            continue
        if not predicate_1 in predicate_prob_dict.keys() or not predicate_2 in predicate_prob_dict[predicate_1]:
            sim = fuzz.WRatio(label_1, label_2) / 100
            prob = 0.6 * sim
            predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = prob

# %%
nltk_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def embed_long_sentence(long_sentence):
    sentences = nltk_tokenizer.tokenize(long_sentence)
    
    tokens = {'input_ids': [], 'attention_mask': []}

    max_token = 140
    for sentence in sentences:
        new_tokens = tokenizer.encode_plus(sentence, return_tensors="pt", max_length=max_token, padding='max_length')
        tokens['input_ids'].append(new_tokens['input_ids'][0][:max_token])
        tokens['attention_mask'].append(new_tokens['attention_mask'][0][:max_token])

    tokens['input_ids'] = torch.stack(tokens['input_ids'])
    tokens['attention_mask'] = torch.stack(tokens['attention_mask'])
    
    outputs = model(**tokens)
    
    embeddings = outputs.last_hidden_state
    
    attention_mask = tokens['attention_mask']
    
    mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()

    masked_embeddings = embeddings * mask
    
    summed = torch.sum(masked_embeddings, 1)

    summed_mask = torch.clamp(mask.sum(1), min=1e-9)

    mean_pooled = summed / summed_mask
    
    return mean_pooled.detach().numpy()

# %%
def get_label_vec_dict(df):
    LABEL = 'corpus stopword label'

    df_label_set = set(df[LABEL])
    df_label_vec_dict = dict()

    for label in tqdm(df_label_set):
        if not label:
            continue

        df_label_vec_dict[label] = embed_long_sentence(label)
    return df_label_vec_dict

# %%
graph_2_label_vec_dict = get_label_vec_dict(graph_2_inv_func_df)
# Out:
#   0%|          | 0/194 [00:00<?, ?it/s]

# %%
LABEL = 'corpus stopword label'

for _, row in tqdm(graph_1_inv_func_df.iterrows(), total=len(graph_1_inv_func_df)):
    label_1 = row[LABEL]
    predicate_1 = row['predicate']
    if not label_1:
        continue
    vec_1 = embed_long_sentence(label_1)
    
    for _, row_2 in graph_2_inv_func_df.iterrows():
        predicate_2 = row_2['predicate']
        label_2 = row_2[LABEL]
        
        if not label_2:
            continue
        
        if predicate_prob_dict[predicate_1][predicate_2] > 0.5:
            continue
        
        vec_2 = graph_2_label_vec_dict[row_2[LABEL]]
        
        similarities = cosine_similarity(vec_1, vec_2)
        max_similarity = max(map(max, similarities))
        prob = 0.5 * max_similarity
        
        if prob > predicate_prob_dict[predicate_1][predicate_2]:
            predicate_prob_dict[predicate_1][predicate_2] = prob
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]

# %%
for pred_1 in predicate_prob_dict.keys():
    pred_1_dict = predicate_prob_dict[pred_1]
    highest_sim_predicate = max(pred_1_dict, key=lambda x: pred_1_dict[x])
    print(pred_1)
    print(highest_sim_predicate)
    print(pred_1_dict[highest_sim_predicate])
    print('____')
# Out:
# http://dbkwik.webdatacommons.org/ontology/abstract
# http://dbkwik.webdatacommons.org/ontology/abstract
# 1.0
# ____
# http://xmlns.com/foaf/0.1/depiction
# http://xmlns.com/foaf/0.1/depiction
# 1.0
# ____
# http://purl.org/dc/terms/subject
# http://purl.org/dc/terms/subject
# 1.0
# ____
# http://xmlns.com/foaf/0.1/thumbnail
# http://xmlns.com/foaf/0.1/thumbnail
# 1.0
# ____
# http://www.w3.org/2000/01/rdf-schema#comment
# http://www.w3.org/2000/01/rdf-schema#comment
# 1.0
# ____
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1.0
# ____
# http://www.w3.org/2004/02/skos/core#broader
# http://www.w3.org/2004/02/skos/core#broader
# 1.0
# ____
# http://dbkwik.webdatacommons.org/ontology/wikiPageDisambiguates
# http://dbkwik.webdatacommons.org/ontology/wikiPageDisambiguates
# 1.0
# ____
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# 1.0
# ____
# http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLinkText
# http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLinkText
# 1.0
# ____
# http://dbkwik.webdatacommons.org/ontology/wikiPageExternalLink
# http://dbkwik.webdatacommons.org/ontology/wikiPageExternalLink
# 1.0
# ____
# http://dbkwik.webdatacommons.org/ontology/thumbnail
# http://dbkwik.webdatacommons.org/ontology/thumbnail
# 1.0
# ____
# http://www.w3.org/2004/02/skos/core#altLabel
# http://www.w3.org/2004/02/skos/core#altLabel
# 1.0
# ____
# http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLink
# http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLink
# 1.0
# ____
# http://www.w3.org/2004/02/skos/core#related
# http://www.w3.org/2004/02/skos/core#related
# 1.0
# ____
# http://purl.org/dc/elements/1.1/rights
# http://purl.org/dc/elements/1.1/rights
# 1.0
# ____
# http://www.w3.org/2004/02/skos/core#prefLabel
# http://www.w3.org/2004/02/skos/core#prefLabel
# 1.0
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/father
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/father
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/gender
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gender
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/image
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/occupation
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/occupation
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/died
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/died
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/status
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/prev
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/next
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/actor
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/born
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/born
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/date
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/combatant
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/combatant
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/capital
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/rank
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/rank
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/children
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/children
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/affiliation
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/strength
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/strength
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/location
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/location
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/result
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/result
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/species
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/season
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/season
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/director
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/planet
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planet
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/format
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/quadrant
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/quadrant
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/planets
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planets
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/mother
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mother
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/headOfState
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfState
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/language
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/language
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/spouse
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/spouse
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/size
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/size
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/headOfGovernment
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfGovernment
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/founded
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/founded
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/military
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/military
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/caption
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/majorSpecies
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/majorSpecies
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/currency
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/currency
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/relatives
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/judiciary
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/judiciary
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/weight
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weight
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/legislature
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/legislature
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/draft
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abbr
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abbr
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/width
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/width
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/guest
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/guest
# 0.9
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/pages
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pages
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/name
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/class
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/author
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/writer
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/year
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/publisher
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/type
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/series
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/placeOfBirth
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/placeOfBirth
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/released
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/artist
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artist
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/stardate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardate
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/speed
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/speed
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/registry
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/registry
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/title
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/length
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/armament
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armament
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/crew
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/decks
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decks
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/height
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/height
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/beam
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/beam
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/launched
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/launched
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/diameter
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/diameter
# 0.8
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/stitle
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title
# 0.7
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/simage
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.7
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.7
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagea
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.7
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imaged
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.7
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagecap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/placeOfDeath
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/place
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nairdateyear
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/time
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/birthName
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aprevreleasedinall
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/losses
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital
# 0.3893788456916809
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/characters
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/reference
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/circumference
# 0.43636363636363634
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/published
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher
# 0.5333333333333333
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/editor
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director
# 0.4497464895248413
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nepisode
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextproducedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aprevproducedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nairdateday
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsdirectedby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsdate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextreleasedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/datestatus
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/commander
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nseason
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/season
# 0.57
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/issue
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pressure
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/active
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/isbn
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author
# 0.40936189889907837
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/publication
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption
# 0.49846153846153846
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagesurface
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sairdatemonth
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageorbital
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sproductionserialnumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aself
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives
# 0.43302908539772034
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aprevreleasedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/appearance
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nserialairdate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abruntime
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime
# 0.46666666666666673
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/actualSpecies
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dateOfBirth
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dateOfDeath
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dt
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wswrittenby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer
# 0.45000000000000007
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/operator
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/roles
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor
# 0.40118372440338135
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/relative
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives
# 0.5647058823529411
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aftertrek
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/aff
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/page
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pages
# 0.5333333333333333
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nnthreleasedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/issues
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conflict
# 0.43531590700149536
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/novels
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author
# 0.43690061569213867
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfuv
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev
# 0.4039427638053894
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/rating
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nnthreleasedinall
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/coverDate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/label
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/music
# 0.4109363853931427
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/developer
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created
# 0.45180195569992065
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc1nextpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nreleaseday
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released
# 0.47879999999999995
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsteleplayby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/plays
# 0.48
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextinuniversetimeline
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextreleasedinall
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abpublisher
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher
# 0.57
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abisbn
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn
# 0.36000000000000004
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc0partcount
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/unit
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cover
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/discs
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nairdatedayRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/composer
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/conflictName
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/periodical
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation
# 0.4229641258716583
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nnthproducedinseries
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/defenses
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/defense
# 0.5599999999999999
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsstoryby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp
# 0.3718014657497406
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsarc0desc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code
# 0.38475
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/surfacecap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/surface
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/maritalStatus
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/episodes
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.4232957363128662
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/awardsForTrek
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor
# 0.40506085753440857
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/ab
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abrev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/actualIdentity
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aprevinuniversetimeline
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/creator
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/owner
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nairdateyearRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/disambig
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dur
# 0.36241787672042847
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cards
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc0nextpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abpublished
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/ababridged
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sibling
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/siblings
# 0.5599999999999999
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/chrono
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/abreadby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/genres
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/genre
# 0.5454545454545454
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/id
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc0partnumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextreleasedinseriesRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/holoprogram
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/color
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sairdatemonthRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc0prevpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/bloodType
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/orchestrator
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor
# 0.48
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/originalPurpose
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originalRun
# 0.45599999999999996
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/text
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcnext
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/productionRun
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nativeSpecies
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/subtitles
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aprevreleasedinseriesRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/date2s
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/production
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/logo
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship
# 0.46198081970214844
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/menu
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mission
# 0.4330318868160248
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/satellites
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planets
# 0.4290032684803009
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/reDate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/reId
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship
# 0.4404670000076294
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dis
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/distance
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dubbed
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created
# 0.44854897260665894
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/timespan
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.36603468656539917
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/mass
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assignment
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cover2s
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/activationDate
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nserialairdateRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/intelligenceService
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/intel
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sprev
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.5333333333333333
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sd
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/color
# 0.42782750725746155
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/image2cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nnthreleasedinseriesRemastered
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/requirements
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mission
# 0.4398643672466278
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/character
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/position
# 0.4382914900779724
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfnf
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn
# 0.4
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/awgt
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weight
# 0.4
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/pid
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.4093320965766907
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/orbitalcap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planetName
# 0.3853144645690918
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anum
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/epNum
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/perpack
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/file
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/registry
# 0.4310448169708252
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/studio
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/system
# 0.4150402545928955
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/last
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/craft
# 0.4464437961578369
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc1partnumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/birthname
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfit
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/distance
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfgp
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp
# 0.4
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/symbol
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/faction
# 0.468009352684021
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc1partcount
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/snext
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.5333333333333333
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsproducedby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/producer
# 0.4421052631578948
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsarc1desc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/addmusic
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/music
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/run
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nextchrono
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/network
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageb
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.57
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/pop
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop
# 0.5142857142857143
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/rack
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/docking
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/platform
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/form
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/upc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/logo3cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gov
# 0.41040000000000004
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/serialNumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfaz
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev
# 0.37950122356414795
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsscreenplayby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/plays
# 0.48
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/titlecard
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc1prevpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cover1s
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/perbox
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type
# 0.4185205101966858
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/prevchrono
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/partOf
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/partof
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc2nextpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/od
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dates
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardates
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfvu
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp
# 0.3927846848964691
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/sreleasemonth
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released
# 0.504
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/date1s
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cast
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/twoimg
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dur
# 0.37599655985832214
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/stitlecard
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/soId
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vicePresident
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc3prevpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cargo
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageCaption
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsarc2desc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image2a
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nreleaseyear
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cid
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagealt
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc3partcount
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/unit
# 0.4628571428571429
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/orchestra
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagescreen
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc2prevpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc2partnumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc2partcount
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image2a
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/formatBottom
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/eps
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/nicam
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/parents
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mother
# 0.4645642340183258
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/bfeaturelength
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cards/pack
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yard
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagescreencap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/castcap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/agencyName
# 0.4113042652606964
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/occcupation
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/occupation
# 0.5714285714285713
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/-Aself
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end
# 0.432
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/namev
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name
# 0.5333333333333333
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cast2cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfxb
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vfx
# 0.41044408082962036
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/maritialStatus
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/itemtype
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/%5B%5Bfile%5D%5DAself
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime
# 0.3675999641418457
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/isFormat
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/form
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfvo
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageSize
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/logoalt
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/float
# 0.4
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/percase
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/ship
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shiploss
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagec
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.57
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dfyt
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft
# 0.4
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageorbitalcap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/fsk
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cp
# 0.37275153398513794
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/affilaition
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation
# 0.5454545454545454
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/affilation
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation
# 0.5714285714285713
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/gemder
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gender
# 0.5000000000000001
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagesurfacecap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/awards
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor
# 0.49090909090909085
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/readby
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head
# 0.44999999999999996
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/wsarc3desc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code
# 0.38475
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/aarc3nextpart
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/shipcap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship
# 0.401860773563385
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/logo2cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gov
# 0.41040000000000004
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/conductor
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/martialStatus
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imageCap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/dissolved
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created
# 0.4504087269306183
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/formatTop
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/imagecap.
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/volume
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series
# 0.44263577461242676
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/snId
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vicePresident
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/stableCrew
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/3rdimg
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/milcom
# 0.36714649200439453
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/maxcrew
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/anextinoversetimeline
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/image3cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/bbfc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/url
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/girlFriend
# 0.41040000000000004
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/disks
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/diameter
# 0.4320925176143646
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cslnyears
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/oflc
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/cast3cap
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/paage
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/age
# 0.54
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/packs/box
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/place
# 0.405
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/narc3partnumber
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber
# 0.513
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/written
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer
# 0.46153846153846145
# ____
# http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/website
# http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/size
# 0.405
# ____
