# %%
from rdflib import Graph, URIRef, Namespace, Literal, XSD, RDF
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from tqdm.autonotebook import tqdm
import pandas as pd
from copy import deepcopy
import numpy
from sklearn.metrics.pairwise import cosine_similarity
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import defaultdict
from rapidfuzz import process, fuzz, distance
import math

import torch
from transformers import BertTokenizer
from transformers import BertModel
from sklearn.metrics.pairwise import cosine_similarity

import concurrent.futures
# Out:
# /var/folders/6f/k2t20zbs4db5khp6mgdq_06m0000gn/T/ipykernel_99286/2719750620.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
GRAPH_1 = ""
GRAPH_1_INV_FUNC_PATH = ''

GRAPH_2 = ""
GRAPH_2_INV_FUNC_PATH = ''

#GRAPH_2 = "http://localhost:9999/bigdata/sparql"
SUBJECT = 'subject'
PREDICATE = 'predicate'
INVERSE_FUNCTIONALITY = 'inverse_functionality'
INVERSABILITY = 'inversability'
MAX_LENGTH_FULL_MATCH = 10000
LABEL_PREDICATE = "http://www.w3.org/2000/01/rdf-schema#label"
FILE_FOLDER = "ma-se-all-labels/"
GRAPH_1_ABSTRACT = "http://dbkwik.webdatacommons.org/ontology/abstract"
GRAPH_2_ABSTRACT = "http://dbkwik.webdatacommons.org/ontology/abstract"

# %%
graph_1_inv_func_df = pd.read_csv(GRAPH_1_INV_FUNC_PATH)

#graph_1_predicate_list = threshold_graph_1_inv_func_df[PREDICATE].tolist()

graph_1 = Graph()
graph_1.parse(GRAPH_1)
# Out:
# <Graph identifier=N726c9abf650b4870b975c73959716b04 (<class 'rdflib.graph.Graph'>)>

# %%
graph_2_inv_func_df = pd.read_csv(GRAPH_2_INV_FUNC_PATH)

#graph_2_predicate_list = threshold_graph_2_inv_func_df[PREDICATE].tolist()

graph_2 = Graph()
graph_2.parse(GRAPH_2)
#graph_2 = Graph("SPARQLStore")
#graph_2.open(GRAPH_2)
# Out:
# <Graph identifier=N04ac22a86235468e90f8473c6dbbe0e8 (<class 'rdflib.graph.Graph'>)>

# %%
def get_label_graph(graph, predicate_df, uri_column):
    predicate_label_list = list()
    LABEL = "http://www.w3.org/2000/01/rdf-schema#label"
    ALT_LABEL = "http://www.w3.org/2004/02/skos/core#altLabel"
    label_predicate = URIRef(LABEL)
    alt_label_predicate = URIRef(ALT_LABEL)
    for index, row in tqdm(predicate_df.iterrows(), total=len(predicate_df)):
        search_uriref = URIRef(row[uri_column])
        label_list = list()
        for label in graph.objects(search_uriref, label_predicate):
            label_list.append(str(label))
        for label in graph.objects(search_uriref, alt_label_predicate):
            label_list.append(str(label))
        predicate_label_list.append(label_list)
    return predicate_label_list

# %%
def calculate_similarity_using_label(df_1, df_2, uri_column):
    label_list_1 = get_label_graph(graph_1, df_1, uri_column)
    df_1['label'] = label_list_1
    
    label_list_2 = get_label_graph(graph_2, df_2, uri_column)
    df_2['label'] = label_list_2
    
    uri_set_1 = set(df_1[uri_column])
    uri_set_2 = set(df_2[uri_column])
    
    prob_dict = dict()
    
    for uri_1 in uri_set_1:
        if uri_1 in uri_set_2:
            prob_dict.setdefault(uri_1, {})
            prob_dict[uri_1][uri_1] = 1.0
    
    return prob_dict

# %%
def match_labels(prob_dict, df_1, df_2, label_column, max_score, uri_column):
    unique_labels = set()
    for label_list in df_1[label_column]:
        unique_labels.update(label_list)
    #print(unique_labels)
    df_1_label_dict = {label: [] for label in unique_labels}
    for index, row in df_1.iterrows():
        for label in row[label_column]:
            df_1_label_dict[label].append(row[uri_column])
    
    if '' in df_1_label_dict:
        del df_1_label_dict['']
    
    for _, row in tqdm(df_2.iterrows(), total=len(df_2), desc="match labels"):
        labels = row[label_column]
        uri_2 = row[uri_column]
        for label in labels:
            if label in df_1_label_dict:
                for uri_1 in df_1_label_dict[label]:
                    if uri_1 in prob_dict and uri_2 in prob_dict[uri_1]:
                        continue
                    prob_dict.setdefault(uri_1, {})[uri_2] = max_score

# %%
def normalize_string(s):
    # remove parenthesis
    s = re.sub("[\(\[].*?[\)\]]", "", s)
    # remove punctuation
    s = s.translate(str.maketrans('', '', string.punctuation))
    # split the string at uppercase letters and digits and join with spaces
    s = re.sub(r'([a-z])([A-Z])', r'\1 \2', s)
    s = re.sub(r'([A-Z])([A-Z][a-z])', r'\1 \2', s)
    s = re.sub(r'([a-zA-Z])(\d)', r'\1 \2', s)
    s = re.sub(r'(\d)([a-zA-Z])', r'\1 \2', s)
    # replace underscores with spaces
    s = s.replace('_', ' ')
    # remove multiple consecutive spaces and leading/trailing spaces
    s = ' '.join(s.split()).strip()
    # convert to lowercase and return
    return s.lower()

# %%
nltk.download('stopwords') # download stop words list

stop_words = set(stopwords.words('english')) # set of English stop words

def remove_stopwords(s):
    words = s.split() # split text into individual words

    filtered_words = [word for word in words if not word.lower() in stop_words] # remove stop words

    filtered_text = ' '.join(filtered_words)
    return filtered_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yamamotobikutorueiichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_corpus_specific_stopword(graph_df):
    doc_freq = defaultdict(int)

    for _, row in graph_df.iterrows():
        doc = ' '.join(row['stopword label'])
        words = set(word_tokenize(doc))
        for word in words:
            doc_freq[word] += 1
            
    total_docs = len(graph_df)
    corpus_stopwords = set()
    for word, freq in doc_freq.items():
        if freq / total_docs > 0.2: # word appears in more than 20% of documents
            corpus_stopwords.add(word)    
    label_list = list()
    for _, row in graph_df.iterrows():
        filtered_text_list = list()
        for label in row['stopword label']:
            words = word_tokenize(label)
            filtered_words = [word for word in words if not word.lower() in corpus_stopwords]
            filtered_text = ' '.join(filtered_words)
            filtered_text_list.append(filtered_text)
        label_list.append(filtered_text_list)
    
    graph_df['corpus stopword label'] = label_list

# %%
nltk_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def embed_long_sentence(long_sentence):
    sentences = nltk_tokenizer.tokenize(long_sentence)
    
    tokens = {'input_ids': [], 'attention_mask': []}

    max_token = 140
    for sentence in sentences:
        new_tokens = tokenizer.encode_plus(sentence, return_tensors="pt", max_length=max_token, padding='max_length')
        tokens['input_ids'].append(new_tokens['input_ids'][0][:max_token])
        tokens['attention_mask'].append(new_tokens['attention_mask'][0][:max_token])

    tokens['input_ids'] = torch.stack(tokens['input_ids'])
    tokens['attention_mask'] = torch.stack(tokens['attention_mask'])
    
    outputs = model(**tokens)
    
    embeddings = outputs.last_hidden_state
    
    attention_mask = tokens['attention_mask']
    
    mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()

    masked_embeddings = embeddings * mask
    
    summed = torch.sum(masked_embeddings, 1)

    summed_mask = torch.clamp(mask.sum(1), min=1e-9)

    mean_pooled = summed / summed_mask
    
    return mean_pooled.detach().numpy()

# %%
def get_label_vec_dict(df):
    LABEL = 'corpus stopword label'

    #df_label_set = set(df[LABEL])
    unique_labels = set().union(*df[LABEL])

    df_label_vec_dict = dict()

    for label in tqdm(unique_labels):
        if not label:
            continue

        df_label_vec_dict[label] = embed_long_sentence(label)
    return df_label_vec_dict

# %%
def apply_match_label(prob_dict, df_1, df_2, uri_column, label_to_apply, new_label, max_score):
    df_1[new_label] = df_1[label_to_apply].apply(lambda label_list: [normalize_string(label) for label in label_list])

    df_2[new_label] = df_2[label_to_apply].apply(lambda label_list: [normalize_string(label) for label in label_list])
    
    match_labels(prob_dict, df_1, df_2, new_label, max_score, uri_column)

# %%
def calculate_prob_dict(df_1, df_2, uri_column):
    prob_dict = calculate_similarity_using_label(df_1, df_2, uri_column)
    
    match_labels(prob_dict, df_1, df_2, 'label', 0.9, uri_column)

    apply_match_label(prob_dict, df_1, df_2, uri_column, 'label', 'normalized label', 0.8)
    apply_match_label(prob_dict, df_1, df_2, uri_column, 'normalized label', 'stopword label', 0.7)

    remove_corpus_specific_stopword(df_1)
    remove_corpus_specific_stopword(df_2)
    
    # Fuzzy and BERT match only for list with less than MAX_LENGTH_FULL_MATCH
    if len(df_1) > MAX_LENGTH_FULL_MATCH or len(df_2) > MAX_LENGTH_FULL_MATCH:
        return prob_dict

    # Match using fuzzy string
    LABEL = 'corpus stopword label'
    for _, row in tqdm(df_1.iterrows(), total=len(df_1), desc='Corpus stopword match'):
        labels_1 = row[LABEL]
        uri_1 = row[uri_column]
        if not labels_1:
            continue

        for _, row_2 in df_2.iterrows():
            labels_2 = row_2[LABEL]
            uri_2 = row_2[uri_column]
            if not labels_2:
                continue
            if not uri_1 in prob_dict.keys() or not uri_2 in prob_dict[uri_1]:
                for label_1 in labels_1:
                    max_sim = 0.0
                    for label_2 in labels_2:
                        sim = fuzz.WRatio(label_1, label_2) / 100
                        prob = 0.6 * sim
                        if prob > max_sim:
                            max_sim = prob
                    prob_dict.setdefault(uri_1, {})[uri_2] = max_sim           
    
    # Match using BERT
    graph_1_label_vec_dict = get_label_vec_dict(df_1)
    graph_2_label_vec_dict = get_label_vec_dict(df_2)
    
    LABEL = 'corpus stopword label'
    for _, row in tqdm(df_2.iterrows(), total=len(df_2)):
        if uri_1 in prob_dict and uri_2 in prob_dict[uri_1] and prob_dict[uri_1][uri_2] > 0.5:
                continue
                
        labels_2 = row[LABEL]
        uri_2 = row[uri_column]
        if not labels_2:
            continue
        

        for _, row_1 in df_1.iterrows():
            uri_1 = row_1[uri_column]
            labels_1 = row_1[LABEL]

            if not labels_1:
                continue
            
            max_sim = 0.0
            for label_1 in labels_1:
                if not label_1:
                    continue
                for label_2 in labels_2:
                    if not label_2:
                        continue
                    vec_1 = graph_1_label_vec_dict[label_1]
                    vec_2 = graph_2_label_vec_dict[label_2]

                    similarities = cosine_similarity(vec_1, vec_2)
                    max_similarity = max(map(max, similarities))
                    prob = 0.5 * max_similarity
                    if prob > max_sim:
                        max_sim = prob

            if max_sim > prob_dict[uri_1][uri_2]:
                prob_dict[uri_1][uri_2] = max_sim
    
    return prob_dict

# %%
predicate_prob_dict = calculate_prob_dict(graph_1_inv_func_df, graph_2_inv_func_df, 'predicate')
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]
#   0%|          | 0/218 [00:00<?, ?it/s]
# match labels:   0%|          | 0/218 [00:00<?, ?it/s]
# match labels:   0%|          | 0/218 [00:00<?, ?it/s]
# match labels:   0%|          | 0/218 [00:00<?, ?it/s]
# Corpus stopword match:   0%|          | 0/342 [00:00<?, ?it/s]
#   0%|          | 0/320 [00:00<?, ?it/s]
#   0%|          | 0/197 [00:00<?, ?it/s]
#   0%|          | 0/218 [00:00<?, ?it/s]

# %%
predicate_sem_prob_list = list()

for pred_1, pred_2_dict in predicate_prob_dict.items():
    for pred_2 in pred_2_dict:
        predicate_sem_prob_list.append({
            'p1': pred_1,
            'p2': pred_2,
            'sim': pred_2_dict[pred_2]
        })

# %%
predicate_sem_prob_df = pd.DataFrame(predicate_sem_prob_list)
predicate_sem_prob_df.to_csv(FILE_FOLDER + 'predicate_sem_prob.csv')

# %%
threshold_graph_1_inv_func_df = graph_1_inv_func_df[graph_1_inv_func_df[INVERSABILITY] > 0.25]
threshold_graph_2_inv_func_df = graph_2_inv_func_df[graph_2_inv_func_df[INVERSABILITY] > 0.25]

# %%
def get_graph_classes(graph):
    query = """
        select * {?s a owl:Class.}
        """
    class_list = list()
    
    for res in graph.query(query):
        class_list.append(res[0])
    return class_list

# %%
graph_1_class_list = get_graph_classes(graph_1)
graph_2_class_list = get_graph_classes(graph_2)

class_1_df = pd.DataFrame()
class_1_df['class'] = graph_1_class_list
class_2_df = pd.DataFrame()
class_2_df['class'] = graph_2_class_list

class_sem_prob_dict = calculate_prob_dict(class_1_df, class_2_df, 'class')
# Out:
#   0%|          | 0/181 [00:00<?, ?it/s]
#   0%|          | 0/283 [00:00<?, ?it/s]
# match labels:   0%|          | 0/283 [00:00<?, ?it/s]
# match labels:   0%|          | 0/283 [00:00<?, ?it/s]
# match labels:   0%|          | 0/283 [00:00<?, ?it/s]
# Corpus stopword match:   0%|          | 0/181 [00:00<?, ?it/s]
#   0%|          | 0/179 [00:00<?, ?it/s]
#   0%|          | 0/283 [00:00<?, ?it/s]
#   0%|          | 0/283 [00:00<?, ?it/s]

# %%
class_sem_prob_list = list()

for class_1, class_2_dict in class_sem_prob_dict.items():
    for class_2 in class_2_dict:
        class_sem_prob_list.append({
            'c1': class_1,
            'c2': class_2,
            'sim': class_2_dict[class_2]
        })

# %%
class_sem_prob_df = pd.DataFrame(class_sem_prob_list)
class_sem_prob_df.to_csv(FILE_FOLDER + 'class_sem_prob.csv')

# %%
def get_graph_entities(graph):
    query = """
        SELECT DISTINCT ?s
        WHERE {
          # ?s <http://www.w3.org/2000/01/rdf-schema#label> ?o.
        }"""
    entity_list = list()
    
    for res in graph.query(query):
        entity_list.append(str(res[0]))
    return entity_list

# %%
graph_1_entity_list = get_graph_entities(graph_1)
graph_2_entity_list = get_graph_entities(graph_2)

entity_1_df = pd.DataFrame()
entity_1_df['entity'] = graph_1_entity_list
entity_2_df = pd.DataFrame()
entity_2_df['entity'] = graph_2_entity_list

entity_sem_prob_dict = calculate_prob_dict(entity_1_df, entity_2_df, 'entity')
# Out:
#   0%|          | 0/49959 [00:00<?, ?it/s]
#   0%|          | 0/15373 [00:00<?, ?it/s]
# match labels:   0%|          | 0/15373 [00:00<?, ?it/s]
# match labels:   0%|          | 0/15373 [00:00<?, ?it/s]
# match labels:   0%|          | 0/15373 [00:00<?, ?it/s]

# %%
entity_sem_prob_list = list()

for entity_1 in entity_sem_prob_dict.keys():
    for entity_2 in entity_sem_prob_dict[entity_1].keys():
        entity_sem_prob_list.append({
            'e1': entity_1,
            'e2': entity_2,
            'sim': entity_sem_prob_dict[entity_1][entity_2]
        })

# %%
entity_sem_prob_df = pd.DataFrame(entity_sem_prob_list)

# %%
entity_sem_prob_df.to_csv(FILE_FOLDER + 'entity_sem_prob.csv')

# %%
threshold_graph_1_inv_func_df = threshold_graph_1_inv_func_df[threshold_graph_1_inv_func_df['predicate'].str.contains(LABEL_PREDICATE) == False]
threshold_graph_2_inv_func_df = threshold_graph_2_inv_func_df[threshold_graph_2_inv_func_df['predicate'].str.contains(LABEL_PREDICATE) == False]

# %%
threshold_graph_1_inv_func_df
# Out:
#      Unnamed: 0                                          predicate  \
# 1             1             http://purl.org/dc/elements/1.1/rights
# 8             8       http://www.w3.org/2004/02/skos/core#altLabel
# 9             9  http://dbkwik.webdatacommons.org/memory-alpha....
# 10           10  http://dbkwik.webdatacommons.org/memory-alpha....
# 11           11  http://dbkwik.webdatacommons.org/ontology/wiki...
# ..          ...                                                ...
# 337         337  http://dbkwik.webdatacommons.org/memory-alpha....
# 338         338  http://dbkwik.webdatacommons.org/memory-alpha....
# 339         339  http://dbkwik.webdatacommons.org/memory-alpha....
# 340         340  http://dbkwik.webdatacommons.org/memory-alpha....
# 341         341  http://dbkwik.webdatacommons.org/memory-alpha....
#
#      functionality  inverse_functionality  inversability             label  \
# 1         1.000000               0.500000       0.500000                []
# 8         0.704954               1.000000       0.704954                []
# 9         0.918749               0.983028       0.903156            [Name]
# 10        0.994955               0.421982       0.419853  [Place of birth]
# 11        0.437566               0.875140       0.382932                []
# ..             ...                    ...            ...               ...
# 337       1.000000               1.000000       1.000000             [UPC]
# 338       1.000000               1.000000       1.000000       [image3cap]
# 339       1.000000               1.000000       1.000000          [Volume]
# 340       1.000000               1.000000       1.000000             [FSK]
# 341       1.000000               1.000000       1.000000     [occcupation]
#
#      normalized label    stopword label corpus stopword label
# 1                  []                []                    []
# 8                  []                []                    []
# 9              [name]            [name]                [name]
# 10   [place of birth]  [place of birth]      [place of birth]
# 11                 []                []                    []
# ..                ...               ...                   ...
# 337             [upc]             [upc]                 [upc]
# 338     [image 3 cap]     [image 3 cap]         [image 3 cap]
# 339          [volume]          [volume]              [volume]
# 340             [fsk]             [fsk]                 [fsk]
# 341     [occcupation]     [occcupation]         [occcupation]
#
# [256 rows x 9 columns]

# %%
literal_y1_dict = dict()
used_p1_dict = dict()
graph_1_predicate_list = list()

for index, row in tqdm(threshold_graph_1_inv_func_df.iterrows(), total=len(threshold_graph_1_inv_func_df)):
    predicate = row[PREDICATE]
    predicate_uri = URIRef(predicate)

    if sum(1 for _ in graph_1.subject_objects(predicate_uri)) < 5:
        continue
    
    graph_1_predicate_list.append(predicate)
    
    #for s, p, o in graph_1.triples((None, predicate_uri, None)):
    #    if type(o) != Literal or not isinstance(o, Literal) or not (o.datatype is None or o.datatype == XSD.string or o.datatype == RDF.langString):
    #        continue
    for s, p, o in graph_1.triples((None, predicate_uri, None)):

        #if type(o) != Literal or not isinstance(o, Literal) or not (o.datatype is None or o.datatype == XSD.string or o.datatype == RDF.langString):
        #    continue
        
        if type(o) != Literal or not isinstance(o, Literal):
            continue
        o_value = str(o)
        if o_value not in literal_y1_dict.keys():
            literal_y1_dict[o_value] = list()
        y1_value_list = literal_y1_dict[o_value]
        y1_value_list.append({
            SUBJECT: s,
            PREDICATE: predicate_uri
        })
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]

# %%
y2_matches = dict()
graph_2_predicate_list = list()

for index, row in tqdm(threshold_graph_2_inv_func_df.iterrows(), total=len(threshold_graph_2_inv_func_df)):
    predicate = row[PREDICATE]
    predicate_uri = URIRef(predicate)
    
    if sum(1 for _ in graph_2.subject_objects(predicate_uri)) < 5:
        continue
        
    graph_2_predicate_list.append(predicate)
    
    for s, o in graph_2.subject_objects(predicate_uri):
        #if type(o) != Literal or not isinstance(o, Literal) or not (o.datatype is None or o.datatype == XSD.string or o.datatype == RDF.langString):
        #    continue
        
        if type(o) != Literal or not isinstance(o, Literal):
            continue
        
        # Check if exist match
        o_value = str(o)
        if o_value not in literal_y1_dict.keys():
            continue
            
        if o_value not in y2_matches.keys():
            y2_matches[o_value] = list()
        y2_match_list = y2_matches[o_value]
        y2_match_list.append({
            SUBJECT: s,
            PREDICATE: predicate_uri
        })
# Out:
#   0%|          | 0/167 [00:00<?, ?it/s]

# %%
def get_predicate_prob(predicate_pair_dict, p1, p2):
    if p1 not in predicate_pair_dict.keys():
        predicate_pair_dict[p1] = dict()
    if p2 not in predicate_pair_dict[p1].keys():
        predicate_pair_dict[p1][p2] = 0.1

    return predicate_pair_dict[p1][p2]

# %%
inv_func_1_dict = dict()

for index, row in tqdm(threshold_graph_1_inv_func_df.iterrows(), total=len(threshold_graph_1_inv_func_df)):
    inv_func_1_dict[row['predicate']] = row[INVERSABILITY]
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]

# %%
inv_func_2_dict = dict()

for index, row in tqdm(threshold_graph_2_inv_func_df.iterrows(), total=len(threshold_graph_2_inv_func_df)):
    inv_func_2_dict[row['predicate']] = row[INVERSABILITY]
# Out:
#   0%|          | 0/167 [00:00<?, ?it/s]

# %%
def save_predicate_pair(predicate_pair_counter, x1, p1, y1, x2, p2, y2):
    predicate_pair_counter.append({
        'x1': x1,
        'p1': p1,
        'y1': y1,
        'x2': x2,
        'p2': p2,
        'y2': y2,
    })

# %%
def update_prob_entities(entity_pair_match_dict, x1, x2, p1, p2, prob_y):
    if x1 not in entity_pair_match_dict.keys():
        entity_pair_match_dict[x1] = dict()
    if x2 not in entity_pair_match_dict[x1].keys():
        entity_pair_match_dict[x1][x2] = 1
    #if x1 == 'http://dbkwik.webdatacommons.org/finalfantasy./resource/Toad_(Final_Fantasy_V_enemy)':
    #    print(len(entity_pair_match_dict[x1]))
    
    y1_pred = str(p1)
    y2_pred = str(p2)
    pred_prob_1_2 = get_predicate_prob(predicate_pair_dict_1, y1_pred, y2_pred)
    pred_prob_2_1 = get_predicate_prob(predicate_pair_dict_2, y2_pred, y1_pred)

    new_factor = (1-pred_prob_1_2*inv_func_1_dict[y1_pred] * prob_y) * (1-pred_prob_2_1*inv_func_2_dict[y2_pred] * prob_y)

    entity_pair_match_dict[x1][x2] *= new_factor

    return 1 - entity_pair_match_dict[x1][x2]

# %%
def calculate_entity_prob_using_attribute(entity_triple_match):
    for o_value, y2_match_list in tqdm(y2_matches.items(), desc='Attribute loop', leave=False):
        y1_match_list = literal_y1_dict[o_value]

        for y1_match in y1_match_list:
            y1_subject = y1_match['subject']

            for y2_match in y2_match_list:
                y2_subject = y2_match['subject']


                y1_pred = str(y1_match['predicate'])
                y2_pred = str(y2_match['predicate'])
                sim = update_prob_entities(entity_triple_match, str(y1_subject), str(y2_subject),
                                     y1_pred, y2_pred, 1)

                if sim > 0.1:
                    save_predicate_pair(predicate_pair_counter, str(y1_subject), y1_pred, o_value, str(y2_subject),
                                        y2_pred, o_value)

# %%
def get_inbound_neighbors(graph, predicate_list, y, loaded_neighbors_dict):
    if not y:
        return []
    
    if y in loaded_neighbors_dict.keys():
        return loaded_neighbors_dict[y]
    
    y_url = y
    if type(y_url) != URIRef:
        y_url = URIRef(y)
    
    attempts = 0
    while attempts < 10:
        try:
            neighbor_list = list()
            for s, p in graph.subject_predicates(y_url):
                if str(p) in predicate_list:
                    neighbor_list.append({
                        'p': p,
                        's': s
                    })
            return neighbor_list
        except Exception as e:
            print(e)
            attempts += 1
    loaded_neighbors_dict[y] = neighbor_list
    return neighbor_list

# %%
def update_prob_entity_neighbors(entity_triple_match, y1_neighbors,
                                 y2_neighbors, y_sim, y1, y2):
    for x1 in y1_neighbors:
        for x2 in y2_neighbors:
            x1_str = str(x1['s'])
            x2_str = str(x2['s'])
            p1_str = str(x1['p'])
            p2_str = str(x2['p'])
            sim = update_prob_entities(entity_triple_match, x1_str, x2_str, p1_str, str(x2['p']),
                                 y_sim)
            if sim > 0.1:
                save_predicate_pair(predicate_pair_counter, x1_str, p1_str, str(y1), x2_str, p2_str, str(y2))

# %%
def calculate_entity_prob_using_neighbors(entity_triple_match, entity_pair_dict, loaded_neighbors_dict):
    y1_keys = list(entity_pair_dict.keys())
    for y1 in tqdm(y1_keys, desc='neighbor loop', leave=False):
        y1_neighbors = get_inbound_neighbors(graph_1, graph_1_predicate_list, y1, loaded_neighbors_dict)
        y2_keys = list(entity_pair_dict[y1].keys())
        for y2 in y2_keys:
            y_sim = entity_pair_dict[y1][y2]
            if y_sim < 0.1:
                continue
            
            y2_neighbors = get_inbound_neighbors(graph_2, graph_2_predicate_list, y2, loaded_neighbors_dict)
            update_prob_entity_neighbors(entity_triple_match, y1_neighbors, y2_neighbors, y_sim, y1, y2)

# %%
def get_prob_entity_pair(entity_pair_match_dict, s1, s2):
    if s1 in entity_pair_match_dict.keys() and s2 in entity_pair_match_dict[s1].keys():
        return 1 - entity_pair_match_dict[s1][s2]
    return 0

# %%
def get_set_of_triples_by_predicate(predicate_pair_counter_df, reversed_bool):
    if reversed_bool:
        return predicate_pair_counter_df[['x2', 'p2', 'y2']].drop_duplicates()
    else:
        return predicate_pair_counter_df[['x1', 'p1', 'y1']].drop_duplicates()

# %%
def get_columns(reversed_bool):
    if reversed_bool:
        return {
            'x1': 'x2',
            'p1': 'p2',
            'y1': 'y2',
            'x2': 'x1',
            'p2': 'p1',
            'y2': 'y1'
        }
    else:
        return {
            'x1': 'x1',
            'p1': 'p1',
            'y1': 'y1',
            'x2': 'x2',
            'p2': 'p2',
            'y2': 'y2'
        }

# %%
def calculate_product(matched_row, entity_pair_match_dict):
    x_sim = 1 - entity_pair_match_dict[matched_row['x1']][matched_row['x2']]
    if matched_row['y1'] == matched_row['y2']:
        y_sim = 1
    else:
        y_sim = entity_pair_match_dict[matched_row['y1']][matched_row['y2']]
    return 1 - x_sim * y_sim

# %%
def calculate_sum_by_triple(indexed_df, triple_row):
    matched_triples = indexed_df.join(triple_row)
    return 1.0 - numpy.product(matched_triples['product_element'])

# %%
def calculate_upper_sum(entity_pair_match_dict, predicate_pair_counter_df, unique_triples, p1, p2, reversed_bool):
    columns = get_columns(reversed_bool)
    
    filtered_by_ps_df = predicate_pair_counter_df[predicate_pair_counter_df[columns['p2']].isin([p2])]
    
    grouped_df = filtered_by_ps_df.groupby([columns['x1'], columns['y1']])
    product = grouped_df['product_element'].prod()
    return (1 - product).sum()

# %%
def calculate_lower_sum(entity_pair_match_dict, predicate_pair_counter_df, unique_triples, p1, reversed_bool):
    columns = get_columns(reversed_bool)
    
    grouped_df = predicate_pair_counter_df.groupby([columns['x1'], columns['y1']])
    product = grouped_df['product_element'].prod()
    
    return (1 - product).sum()

# %%
def calculate_x_sim(x1, x2, entity_pair_match_dict, reversed_bool):
    if reversed_bool:
        return 1 - entity_pair_match_dict[x2][x1]
    return 1 - entity_pair_match_dict[x1][x2]

# %%
def calculate_y_sim(y1, y2, entity_pair_match_dict, reversed_bool):
    if y1 == y2:
        return 1
    else:
        if reversed_bool:
            if y2 in entity_pair_match_dict.keys() and y1 in entity_pair_match_dict[y2].keys():
                return 1 - entity_pair_match_dict[y2][y1]
        if y1 in entity_pair_match_dict.keys() and y2 in entity_pair_match_dict[y1].keys():
            return 1 - entity_pair_match_dict[y1][y2]
    return 0

# %%
def calculate_sub_predicates(predicate_sub_relation, predicate_pair_dict, predicate_pair_counter, entity_pair_match_dict, reversed_bool):
    columns = get_columns(reversed_bool)
    predicate_pair_counter_df = pd.DataFrame(predicate_pair_counter)
    
    predicate_pair_counter_df['x_sim'] = predicate_pair_counter_df.apply(lambda x: calculate_x_sim(x[columns["x1"]], x[columns["x2"]], entity_pair_match_dict, reversed_bool), axis=1)
    predicate_pair_counter_df['y_sim'] = predicate_pair_counter_df.apply(lambda x: calculate_y_sim(x[columns["y1"]], x[columns["y2"]], entity_pair_match_dict, reversed_bool), axis=1)

    predicate_pair_counter_df['product_element'] = predicate_pair_counter_df.apply(lambda x: 1.0 - x['x_sim'] * x['y_sim'], axis=1)

    for p1 in tqdm(predicate_pair_dict.keys(), desc='Predicate loop', leave=False):
        filtered_counter = predicate_pair_counter_df[predicate_pair_counter_df[columns['p1']].isin([p1])]
        if len(filtered_counter) < 10:
            for p2 in predicate_pair_dict[p1].keys():
                predicate_sub_relation.setdefault(p1, {})[p2] = 0.0
        unique_triples = get_set_of_triples_by_predicate(filtered_counter, reversed_bool)
        for p2 in predicate_pair_dict[p1].keys():
            predicate_sub_relation.setdefault(p1, {})[p2] = calculate_upper_sum(entity_pair_match_dict, filtered_counter, unique_triples, p1,
                                                              p2, reversed_bool)
        
        lower_sum = calculate_lower_sum(entity_pair_match_dict, filtered_counter, unique_triples, p1, reversed_bool)
        if lower_sum == 0.0:
            continue
        for p2 in predicate_sub_relation[p1].keys():
            predicate_sub_relation[p1][p2] /= lower_sum

# %%
def get_subject_object(graph, predicate):
    attempts = 0
    while attempts < 10:
        try:
            s_o_list = list()
            for s, o in graph.subject_objects(URIRef(predicate)):
                s_o_list.append({
                        'subject': s,
                        'object': o
                    })
            return s_o_list
        except Exception as e:
            print(e)
            attempts += 1
    
    return s_o_list

# %%
def check_if_string(y):
    return type(y) == Literal and y.value and type(y.value) == str

# %%
def calculate_sub_pred_product(entity_pair_match_dict, x1, x2, y1, y2):
    if check_if_string(y1) and check_if_string(y2):
        if y1.value != y2.value:
            return 0.0
        y_value = y1.value
        if y_value not in literal_y1_dict.keys() or y_value not in y2_matches.keys():
            return 0.0
        return entity_pair_match_dict[str(x1)][str(x2)]
    return 0.0

# %%
def save_entity_pairs(i, entity_pair_dict):
    entity_pair_sim_list = list()
    for y1 in entity_pair_dict.keys():
        for y2 in entity_pair_dict[y1].keys():
            entity_pair_sim_list.append({
                "e1": y1,
                "e2": y2,
                "sim": entity_pair_dict[y1][y2]
            })
    entity_sim_df = pd.DataFrame(entity_pair_sim_list)
    entity_sim_df.to_csv(FILE_FOLDER + "entity_sim_" + str(i) + ".csv")

# %%
def save_predicate_pairs_into_df(i, predicate_pair_dict, name):
    predicate_pair_list = list()
    for p1 in predicate_pair_dict.keys():
        for p2 in predicate_pair_dict[p1].keys():
            predicate_pair_list.append({
                "p1": p1,
                "p2": p2,
                "sim": predicate_pair_dict[p1][p2]
            })
    predicate_pair_df = pd.DataFrame(predicate_pair_list)
    predicate_pair_df.to_csv(name + str(i) + ".csv")

# %%
def pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation, reversed_bool):
    new_predicate_pair_dict = dict()
    
    for pred_1, pred_2_dict in pred_sub_relation.items():
        for pred_2 in pred_2_dict:
            if reversed_bool:
                if pred_1 not in new_predicate_pair_dict.get(pred_2, {}):
                    new_predicate_pair_dict.setdefault(pred_2, {})[pred_1] = 0
                new_predicate_pair_dict[pred_2][pred_1] += 0.5 * pred_sub_relation[pred_1][pred_2]
            else:
                if pred_2 not in new_predicate_pair_dict.get(pred_1, {}):
                    new_predicate_pair_dict.setdefault(pred_1, {})[pred_2] = 0
                new_predicate_pair_dict[pred_1][pred_2] += 0.5 * pred_sub_relation[pred_1][pred_2]

    for pred_1 in predicate_prob_dict:
        for pred_2 in predicate_prob_dict[pred_1]:
            if reversed_bool:
                if pred_1 not in new_predicate_pair_dict.get(pred_2, {}):
                    new_predicate_pair_dict.setdefault(pred_2, {})[pred_1] = 0
                new_predicate_pair_dict[pred_2][pred_1] += 0.5 * predicate_prob_dict[pred_1][pred_2]
            else:
                if pred_2 not in new_predicate_pair_dict.get(pred_1, {}):
                    new_predicate_pair_dict.setdefault(pred_1, {})[pred_2] = 0
                new_predicate_pair_dict[pred_1][pred_2] += 0.5 * predicate_prob_dict[pred_1][pred_2]

    return new_predicate_pair_dict

# %%
def get_entity_vec(graph, entity):
    if entity in label_dict:
        return label_dict[entity]
    predicate = URIRef(LABEL_PREDICATE)
    entity_uri = URIRef(entity)
    
    label = str(next(graph.objects(entity_uri, predicate), ""))
    
    if not label:
        return None
    
    vec = embed_long_sentence(label)
    label_dict[entity] = vec
    
    return vec

# %%
def entity_label_bert_similarity(graph_1, graph_2, entity_1, entity_2):
    vec_1 = get_entity_vec(graph_1, entity_1)
    vec_2 = get_entity_vec(graph_2, entity_2)
    
    if vec_1 is None or vec_2 is None:
        return 0.0
    
    similarities = cosine_similarity(vec_1, vec_2)
    return similarities.mean()

# %%
def pre_calc_entity_pair_dict(entity_sem_prob_dict, entity_triple_match):
    entity_prob_dict = dict()
    
    for entity_1, entity_2_dict in entity_sem_prob_dict.items():
        for entity_2 in entity_2_dict:
            entity_prob_dict.setdefault(entity_1, {})[entity_2] = 0.5 * entity_sem_prob_dict[entity_1][entity_2]
    
    for entity_1, entity_2_dict in tqdm(entity_triple_match.items(), desc='entity_pair', leave=False):
        for entity_2 in entity_2_dict:
            if entity_2 not in entity_prob_dict.setdefault(entity_1, {}):
                if 1 - entity_triple_match[entity_1][entity_2] < 0.5:
                    entity_prob_dict.setdefault(entity_1, {})[entity_2] = 0
                else:
                    bert_sim = 0.6 * entity_label_bert_similarity(graph_1, graph_2, entity_1, entity_2)
                    entity_sem_prob_dict.setdefault(entity_1, {})[entity_2] = bert_sim
                    entity_prob_dict.setdefault(entity_1, {})[entity_2] = 0.5 * bert_sim
            entity_prob_dict.setdefault(entity_1, {})[entity_2] += 0.5 * (1 - entity_triple_match[entity_1][entity_2])
            
    return entity_prob_dict

# %%
loaded_neighbors_dict = dict()
pred_sub_relation_1 = dict()
pred_sub_relation_2 = dict()
entity_triple_match = dict()
label_dict = dict()
entity_pair_dict = pre_calc_entity_pair_dict(entity_sem_prob_dict, entity_triple_match)

for i in tqdm(range(10), desc='Main loop'):
    predicate_pair_dict_1 = pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation_1, False)
    predicate_pair_dict_2 = pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation_2, True)
    predicate_pair_counter = list()
    
    save_predicate_pairs_into_df(i, predicate_pair_dict_1, FILE_FOLDER + "predicate_pair_1_")
    save_predicate_pairs_into_df(i, predicate_pair_dict_2, FILE_FOLDER + "predicate_pair_2_")
    
    calculate_entity_prob_using_attribute(entity_triple_match)     
    
    calculate_entity_prob_using_neighbors(entity_triple_match, entity_pair_dict, loaded_neighbors_dict)
    
    entity_pair_dict = pre_calc_entity_pair_dict(entity_sem_prob_dict, entity_triple_match)
    entity_triple_match = dict()
    save_entity_pairs(i, entity_pair_dict)
    
    #calculate_prob_predicates(predicate_pair_dict, new_entity_pair_match_dict)
    calculate_sub_predicates(pred_sub_relation_1, predicate_pair_dict_1, predicate_pair_counter, entity_pair_dict, False)
    calculate_sub_predicates(pred_sub_relation_2, predicate_pair_dict_2, predicate_pair_counter, entity_pair_dict, True)
# Out:
# entity_pair: 0it [00:00, ?it/s]
# Main loop:   0%|          | 0/10 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/4453 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/13980 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/216 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/14499 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16221 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/16726 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16451 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/16948 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16612 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17109 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16647 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17143 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16669 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17164 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16696 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17191 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16708 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17203 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16716 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11331 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/17211 [00:00<?, ?it/s]
# entity_pair:   0%|          | 0/16728 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/339 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/539 [00:00<?, ?it/s]

# %%
def get_abstract_vector(hidden_state_dict, graph, entity, abstract_predicate):
    if entity in hidden_state_dict.keys():
        return hidden_state_dict[entity]
    
    triple = (URIRef(entity), abstract_predicate, None)
    
    if not triple in graph:
        return None
    
    objects = graph.objects(URIRef(entity), abstract_predicate)
    abstract = next(objects, '')
    
    abstract = abstract.strip()
    
    if not abstract:
        return None
    
    embed = embed_long_sentence(abstract)
    hidden_state_dict[entity] = embed
    
    return embed

# %%
def calculate_abstract_similarity(entity_1, entity_2):
    abstract_predicate_1 = URIRef(GRAPH_1_ABSTRACT)
    abstract_predicate_2 = URIRef(GRAPH_2_ABSTRACT)
    
    vec_1 = get_abstract_vector(vector_dict, graph_1, entity_1, abstract_predicate_1)
    vec_2 = get_abstract_vector(vector_dict, graph_2, entity_2, abstract_predicate_2)
    
    if vec_1 is None or vec_2 is None:
        return 0.0

    similarities = cosine_similarity(vec_1, vec_2)
    return max(map(max, similarities))

# %%
query = """
        SELECT ?instance
    WHERE {
      # ?instance rdf:type ?type .
      # ?type a owl:Class.
    }
        """

instance_1_list = list()
for res in graph_1.query(query):
    instance_1_list.append(str(res[0]))

# %%
query = """
        SELECT ?instance
    WHERE {
      # ?instance rdf:type ?type .
      # ?type a owl:Class.
    }
        """

instance_2_list = list()
for res in graph_2.query(query):
    instance_2_list.append(str(res[0]))

# %%
vector_dict = dict()

final_entity_sim_list = list()

for entity_1, entity_2_dict in tqdm(entity_pair_dict.items()):
    
    if entity_1 not in instance_1_list:
        continue
    for entity_2 in entity_2_dict:
        if entity_2 not in instance_2_list:
            continue
        abstract_sim = 0.0
        if entity_2_dict[entity_2] > 0.6:
            abstract_sim = calculate_abstract_similarity(entity_1, entity_2)
            
        final_sim = (2/3) * entity_2_dict[entity_2] + (1/3) * abstract_sim
        
        final_entity_sim_list.append({
            'e1': entity_1,
            'e2': entity_2,
            'sim': final_sim
        })
# Out:
#   0%|          | 0/17223 [00:00<?, ?it/s]

# %%
final_entity_sim_df = pd.DataFrame(final_entity_sim_list)

# %%
final_entity_sim_df.to_csv(FILE_FOLDER + "final_entity_sim.csv")

# %%
entity_pair_dict
# Out:
# {'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Zythmnr': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zythmnr': 0.9487444330415956},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Darth_Malgus': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Malgus': 0.9499997747188904,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Unidentified_Sith_Lord_(Darth_Bane%27s_first_Ruusan_victim)': 0.4,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Malgus_(boss)': 0.48364999711868345,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ascendant_Spear': 0.13819391035431872,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Naga_Sadow': 0.24407332101081802,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Emperor': 0.07463796815001322,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Acina': 0.18276670057181538,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor’s_Hand': 0.13825944814448754,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vitiate': 0.42937175558190277,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Corsair': 0.16927317663015878,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Marka_Ragnos': 0.18651917386903794,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Hyperspace_War': 0.44873075905425586,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Pureblood': 0.11042948407680953,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Sith_War': 0.20634871827821605,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.4215651336433306,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.13235541716951338,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.444472859859476,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/ATC_0': 0.19552768943222554,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban': 0.07367543193695347,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Triumvirate': 0.07367543193695347,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Lord': 0.12353143487785873,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire': 0.058471885830342685,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Scourge': 0.04408316060238865,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Marr': 0.04408316060238865,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor’s_Space_Station': 0.0890530145081389,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcanum': 0.0890530145081389,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor%27s_shuttle': 0.12650633033272196,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.460018944716701,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Wars': 0.21224631766438667,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_Wars:_The_Old_Republic:_Fatal_Alliance': 0.08591486888824845,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rycus_Kilran': 0.06890247788770643,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/323_BTC': 0.08160209449489159,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.19538997200741698,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Andru': 0.079486366158882,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Zash': 0.079486366158882,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Thanaton': 0.079486366158882,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor%27s_Glory': 0.03571743841941433,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/303_BTC': 0.07657676963241922,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/306_BTC': 0.07657676963241922,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/A_Map_for_the_Future': 0.07714366774980375,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cestus': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Atroxa': 0.010288426318989463,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Massassi': 0.006796888897942555,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vette': 0.010405727099072448,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_orbital_security_station': 0.009543714119246038,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Argog': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kory': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Terentatek': 0.006796888897942555,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_Arrival_Port': 0.009592174167735779,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vemrin': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Khem_Val': 0.010405727099072448,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tuk%27ata': 0.006796888897942555,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Warrior': 0.015209142089739613,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Valley_of_the_Dark_Lords': 0.009592174167735779,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ortosin': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ffon_Althe': 0.027979508344385617,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Seferiss': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ragate': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire_(Jedi_Civil_War)': 0.013754883789963812,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Solence': 0.018062756708421,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vaiken_Spacedock': 0.01910538605687523,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gage-class_transport': 0.013956502371024249,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ezran_Outpost': 0.04387485539674307,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sun_Razer': 0.01910538605687523,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fuliginous': 0.07024503986679365,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Javlin': 0.026085987526805687,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Plan_is_Working!': 0.04375262978142558,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:A_Sith_Lord%27s_Rise': 0.0238807412251702,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Battle_Organa': 0.020028646361359814,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Satele_Shan': 0.030716397040322196,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Meetra_Surik': 0.0321604382144266,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kel_Dor': 0.02710110107582253,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad': 0.014503786012420916,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander_Rans': 0.036476999182710024,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander': 0.015402926881981194,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Duros': 0.017544876864267533,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Attack_of_the_Flesh_Raiders': 0.022137185136394677,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Envoy': 0.01903219876393647,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Grand_Master': 0.01741357430383722,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zym': 0.04853574506071595,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ebon_Hawk': 0.0256876859833422,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Revanchist': 0.012605644946200034,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Padawan_Exposed': 0.03756032742658072,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Deal_with_Kendoh': 0.022327951587892303,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Set_the_Table': 0.01640027166664476,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jace_Malcom': 0.023246906599039052,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Stantorrs': 0.024345941235395352},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Voidstar': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voidstar': 0.9359997503926998,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voidstar_(Warzone)': 0.4,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Voidstar': 0.6036260403581928,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/First_Battle_of_Bothawui': 0.0415466299866572,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.04266386650010223,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Praetorian-class_frigate': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Core_Galaxy_Systems_dreadnought': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Starfighter': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/C2-N2': 0.02530332713263117,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vodo-Siosk_Baas%27s_Courier': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Qrrrl_Toq%27s_Starship': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hammerhead-class_cruiser': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Escort_gunship': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/S-250_Chela-class_starfighter': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/S-100_Stinger-class_starfighter': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Shoaneb_Culu%27s_Starship': 0.13300992565728426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cal-class_battleship': 0.13300992565728426},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Vector_Hyllus': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vector_Hyllus': 0.9477304752343307},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Gorse_Bendak': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Bendak_Starkiller': 0.9349566311598694,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Stantorrs': 0.6164267569358999,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tho_Yor': 0.3234700623467548,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Meetra_Surik': 0.47067611482969096,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Unidentified_four-eyed_species_(Jedi_Assembly)': 4.04072195820393e-05,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ooroo%27s_homeworld': 4.04072195820393e-05,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Carrick_Station': 0.10982559649519896,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vaiken_Spacedock': 0.10982559649519896,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Longspur_STAP': 0.16770479538088912,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/42-Y_Civilian_Speeder_Bike': 0.10982559649519896,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korrealis_Commander': 0.10982559649519896,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_of_Coruscant': 0.09477989695102296,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Command_ship': 0.09477989695102296,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Intelligence': 0.1113489884074022,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Intelligence_HQ': 0.1113489884074022,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Telos': 0.04742048158286655,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Transit_Outpost': 0.04742048158286655,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ethan_Remak': 0.11465241706783103,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jace_Malcom': 0.23567981702562024,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sarapin_Assault': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Taspan_Ambush': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ezran_Outpost': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Syvris_Evacuation': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jabiim_Escort': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cartel_Listening_Station': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fondor_Escort': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Javaal_Fleet_Action': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Archenar_Interception': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Llanic_Station_Strike': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Balosar_Outpost': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Makem_Te_Assault': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kovor_Ice_Field': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pakuuni_Defense': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Saleucami_Fleet_Action': 0.08406904378204388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ajunta_Pall': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Garon_Jard': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rajivari': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Lonna_Vash': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Nemo': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ters_Sendon': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cala_Brin': 0.078888098890248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Diplomatic_Service': 0.13021084977197261,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Minister_of_Defense': 0.12403325519311004,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Minister_of_War': 0.12403325519311004,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Minister_of_Intelligence': 0.12403325519311004,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Exchange': 0.07635716653326591,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rakatan_Terraforming_station': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_Chamber': 0.11477897538752846,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Bendak%27s_Blaster': 0.2215842947673084,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/List_of_KotOR_weapons/Ranged_Weapons': 0.01028001993039035,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ashara_Zavros': 0.07786158005071225,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jarael': 0.05899604351571153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Eckard_Lokin': 0.07786158005071225,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rakghoul': 0.05899604351571153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Elara_Dorne': 0.07786158005071225,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Unwelcome_Alliance': 0.08947227539658309,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pierce': 0.07786158005071225,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ferrazid_Hound': 0.05899604351571153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Torian_Cadera': 0.07786158005071225,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Selven': 0.05899604351571153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Trooper': 0.04950093735928468,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Drelliad': 0.03856204733513907,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Corso_Riggs': 0.06221760773341578,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Aric_Jorgan': 0.06221760773341578,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad': 0.12082894977129177,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mantellian_Savrip': 0.047060897362187215,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Minst': 0.1148888708091772,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Frellka': 0.1353654658116587,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Durant': 0.0751196663778046,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Check_In': 0.08196385396512507,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Clan_Cadera': 0.10797131365622303,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/323_BTC': 0.08942123009257547,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Sith_War': 0.16301825317604235,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.1863346835259448,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.1540960079806159,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.08644072639865663,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.21988963471307943,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/ATC_0': 0.11912182673443489,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/303_BTC': 0.047147208448435396,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/306_BTC': 0.047147208448435396,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Wars': 0.18684071398290697,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dorian_Janarus': 0.17474583178321096,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander_Rans': 0.18064064301184746,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Second_Battle_of_Bothawui': 0.01621032460759897,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Battle_of_Bothawui': 2.0451929326203988e-05,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Leontyne_Saresh': 0.11107499748344091,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Chancellor': 0.08097848738841712,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Paran_Am-Ris': 0.20043702746276265,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:A_Sith_Lord%27s_Rise': 0.015395806094486486,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander': 0.07266801948665247,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Duros': 0.06856289651114222,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Envoy': 0.1049269402663014,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cerean': 0.06704509857513752,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_Wars:_The_Old_Republic:_Fatal_Alliance': 0.03951199068900785,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rycus_Kilran': 0.040105148781149735,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.18300030898820957,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Hyperspace_War': 0.17906197718437267,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vitiate': 0.13900389438259897,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Corsair': 0.1488712777653015,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Marka_Ragnos': 0.17677541398744318,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Pureblood': 0.06663796398408539,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cathedral_Ship': 0.03899668798160555,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pius_Dea': 0.02353504233041437,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Naga_Sadow': 0.13712368327339614,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Emperor': 0.04600385941281343,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Acina': 0.05617843778030657,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor’s_Hand': 0.06352467223312136,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Satele_Shan': 0.14941374568503935,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kel_Dor': 0.08353927529755079,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Attack_of_the_Flesh_Raiders': 0.037845141196942766,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Grand_Master': 0.03927044706017868,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zym': 0.1969536888845369,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ebon_Hawk': 0.07144846113857345,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Revanchist': 0.06768209432345001,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tomb_of_Ajunta_Pall_(Explorable_Area)': 0.0643706919281799,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Cruiser': 0.015696478503672118,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Order': 0.013892733671183433,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dantooine_Jedi_Enclave_Council': 0.02138000502498766,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Republic': 0.031329785593090353,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Andru': 0.036042986939982535,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Zash': 0.036042986939982535,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Thanaton': 0.036042986939982535,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Desperate_Times': 0.025244986399963254,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/In_a_Pickle': 0.025244986399963254,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/A_Mule_Out_Of_Water': 0.025244986399963254,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Military': 0.02520231330794981,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Navy': 0.02520231330794981,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Army': 0.02520231330794981,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Set_the_Table': 0.012939862452678086,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Founder': 0.013346737060784652,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Berooken%27s_executive_cruiser': 0.026330888750118353,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Senate': 0.017935395261209686},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Flamethrower': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Flamethrower': 0.9461638943356316,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Menerus': 0.45848450436080196,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_(Tarro_Blood)': 0.4301659316329063,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Wars': 0.5958240954704703,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Sith_War': 0.4895791749607544,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.5385121321929548,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.5555479886846524,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.49315214849934563,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dorian_Janarus': 0.34947739499898584,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander_Rans': 0.3840747250128119,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zym': 0.38795037128770926,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Hyperspace_War': 0.4849230439991099,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.48817440356105013,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Naga_Sadow': 0.37523521034391977,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vitiate': 0.37101888372858066,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jace_Malcom': 0.37484056433471996,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Captain_Grimyk': 0.0020024685986426705,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/List_of_KotOR_weapons/Ranged_Weapons': 0.06151834025138414,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tarro_Blood': 0.152494917023197,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad': 0.18868841157350752,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/323_BTC': 0.1684364256068024,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Shae_Vizla': 0.10275070340195253,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Spirit_of_Vengeance': 0.2343415533772335,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalore': 0.06858598611786709,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalore_the_Lesser': 0.1666108822889189,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Clan_Lok': 0.15047586964411985,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Clan_Ordo': 0.07345770799303752,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Artus_Lok': 0.1531890406370821,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalore_the_Preserver': 0.09845733854254657,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/303_BTC': 0.13831352523319873,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/306_BTC': 0.13831352523319873,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.15470128680909878,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/ATC_0': 0.22915997157581758,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_Wars:_The_Old_Republic:_Fatal_Alliance': 0.10781778489506527,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rycus_Kilran': 0.10308958153439057,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Emperor': 0.07680466903752786,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Acina': 0.21201493193006998,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor’s_Hand': 0.15502250786292493,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Corsair': 0.16170222257620714,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Marka_Ragnos': 0.2095176785778678,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Pureblood': 0.1169132670902851,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire': 0.045891969963816726,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Scourge': 0.03192711697424644,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Marr': 0.03192711697424644,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor’s_Space_Station': 0.08071142462489034,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcanum': 0.08071142462489034,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor%27s_shuttle': 0.07130839806834449,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Lord': 0.10110059598638094,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Republic': 0.15078615867342632,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Leontyne_Saresh': 0.23317248673537477,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Founder': 0.03822524572830183,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Paran_Am-Ris': 0.23202319319573367,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Berooken%27s_executive_cruiser': 0.07622096253822902,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Senate': 0.04916116646915014,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Chancellor': 0.07818900194533684,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Stantorrs': 0.3852083117957329,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ezran_Outpost': 0.15419683999913764,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Set_the_Table': 0.2086899069279028,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Padawan_Exposed': 0.19876603433555312,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Deal_with_Kendoh': 0.17285754094472838,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Plan_is_Working!': 0.18153551798950052,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:A_Sith_Lord%27s_Rise': 0.19210061375368487,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Battle_Organa': 0.14089894593495034,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Check_In': 0.16296953935291075,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Baras': 0.038820203665132724,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_Arrival_Port': 0.036368217251842805,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Warrior': 0.11358701688739853,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Carrick_Station': 0.060357912168422345,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Citadel_Station': 0.060357912168422345,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_orbital_security_station': 0.067145569959488,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fideltin_Rusk': 0.06294185864223883,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/First_Battle_of_Bothawui': 0.13486199373251612,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jabiim_Escort': 0.0639583844086713,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Llanic_Station_Strike': 0.0639583844086713,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Nez_Peron_Sweep': 0.0639583844086713,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pius_Dea': 0.18281397901603685,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cathedral_Ship': 0.22690808914248728,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Envoy': 0.15270399359274706,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cerean': 0.07274792060612262,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander': 0.06490267847009612,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Duros': 0.07520646084399474,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Andru': 0.0888125186312897,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Zash': 0.0888125186312897,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Thanaton': 0.0888125186312897,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Endar_Spire': 0.06569696843760775,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban': 0.06078798696663129,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Triumvirate': 0.06078798696663129,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Satele_Shan': 0.219901422540065,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Meetra_Surik': 0.21883063496510863,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kel_Dor': 0.11663391012863766,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vaiken_Spacedock': 0.04584622458560894,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gage-class_transport': 0.03078683087612244,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sun_Razer': 0.04584622458560894,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Battle_of_Bothawui': 0.0005892039227682888,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Frellka': 0.09147659380278422,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Attack_of_the_Flesh_Raiders': 0.11451660831533261,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Grand_Master': 0.08386398924275956,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ebon_Hawk': 0.12075013846952981,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Revanchist': 0.08103892346711472,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Valkorion': 0.07469997102693227,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Eternal_Fleet_Flagship': 0.0579829812953529,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Front_Lines': 0.08582787310363643,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcann': 0.0707729994452343,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Second_Battle_of_Bothawui': 0.06422497746858474,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor%27s_Glory': 0.05357225550067729,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Cruiser': 0.07112972530465267,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fuliginous': 0.13244749291449426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Javlin': 0.05018429707632266,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Minst': 0.07138187176413346,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Order': 0.07994534222451044,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dantooine_Jedi_Enclave_Council': 0.07392658767733895,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Military': 0.06366186305041005,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Navy': 0.06366186305041005,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Army': 0.06366186305041005,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Telos_Security_Force': 0.030989087561049622,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cestus': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Atroxa': 0.017743926768966523,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Massassi': 0.015292673811252933,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vette': 0.013990870095809127,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Argog': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kory': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Terentatek': 0.015292673811252933,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vemrin': 0.03467908918538204,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Khem_Val': 0.013990870095809127,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tuk%27ata': 0.015292673811252933,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Valley_of_the_Dark_Lords': 0.009923427440336974,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ortosin': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ffon_Althe': 0.03321750512649696,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Seferiss': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ragate': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire_(Jedi_Civil_War)': 0.012685831120861357,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Solence': 0.016042906680117153,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/A_Map_for_the_Future': 0.029809105237933675,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Council': 0.029791250004291392,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ascendant_Spear': 0.012831865948988719,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Eclipse': 0.014900342982915427,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Enemy_Force': 0.016991488175063185,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Combat_Leadership:_Mark_II': 0.03332266524796473,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Moracen': 0.019180474229715194,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pilgrims': 0.016991488175063185,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/K%27lor%27slug_Forager': 0.00857728307289829,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Durant': 0.02411014606326506,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Silvarte': 0.005454432557219391,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Zero_Protocol': 0.008984486054635532,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Breaking_the_Cure': 0.008984486054635532,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Smuggler%27s_Moon': 0.021647336059375688,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Glitch': 0.008984486054635532,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Nar_Shaddaa:_Bonus_Series': 0.020082057991296254,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Kingmaker': 0.01772307178610144,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Regicide': 0.011709973282251929,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Reminisce': 0.0070097498855187235,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Family_Ties': 0.029181585923342857,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Clan_Cadera': 0.10334078120721624,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Clan_Vizla': 0.11261115309993508,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian': 0.01308505476084354},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Voss': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voss_(planet)': 0.949954766077841,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voss': 0.9461603856045917,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Category:Voss': 0.47134637162892173,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voss_(species)': 0.8989957245227751,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Category:Voss_(species)': 0.4,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cathar_(planet)': 0.6278760330407483,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Planets': 0.5751368329254409,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dantooine': 0.5311478182998917,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalore_(planet)': 0.5366872236458083,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Voidstar_(starship)': 0.36299866888201443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Homeworld': 0.5683867141929886,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gormak': 0.5597168332538122,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Xalek': 0.4512497359383446,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Evuk-Nosk': 0.5501444597895628,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gand_(planet)': 0.6289847971209858,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Treasure_Hunting': 0.027558086648582614,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cathar': 0.01401057217114321,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad': 0.2498163409567306,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Set_the_Table': 0.02609326164049447,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Padawan_Exposed': 0.023192570819602354,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Nar_Shaddaa:_Bonus_Series': 0.007490437794194338,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Barrage': 0.007490437794194338,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Ulgo%27s_Revenge': 0.008507732104587773,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Armed_Intervention': 0.015201856803137515,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Frellka': 0.006696019492127392,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Zero_Protocol': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Breaking_the_Cure': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Smuggler%27s_Moon': 0.00889739021617958,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Glitch': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcann': 0.005408165625892247,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Naga_Sadow': 0.006296860677357408,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Family_Ties': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.03460932606087069,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.00658786813729606,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Wars': 0.02508602031368551,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Hyperspace_War': 0.018154611080207494,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/303_BTC': 0.013128135119623296,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/306_BTC': 0.013128135119623296,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.02597505743768891,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.004656930771349765,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.013266904297709048,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/ATC_0': 0.013266904297709048,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/323_BTC': 0.013083082686809189,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Sith_War': 0.02126978613358871,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Citadel_Station': 0.0,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Old_Republic:_Smuggler%27s_Vanguard': 0.004571802368526334},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Kaliyo_Djannis': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kaliyo_Djannis': 0.9447226275113794},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Firebrand': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kaliyo_Djannis': 0.8276627007779587},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Jedi_Order': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Order': 0.9499168062495762,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Category:Jedi_Order': 0.47134637162892173,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi': 0.6179170290825233,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Belth_Allusis': 0.5915167113092672,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Order': 0.5730154916969559,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Academy': 0.5569610402313492,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_training': 0.6095828339782974,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_training': 0.5521882996288558,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_student': 0.36299866888201443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Republic': 0.5771778590506496,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Council': 0.6467231924949477,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dorian_Janarus': 0.6616409951625285,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Paran_Am-Ris': 0.6375718815628781,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.6794080572116713,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Yadira_Ban': 0.4310973829685471,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hallen': 0.4387702173649094,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Avitla': 0.42078888482439736,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mennaus': 0.42060715622294165,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Yuon_Par': 0.49180533357094036,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Orgus_Din': 0.4978655122730672,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zym': 0.6575913232596473,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Satele_Shan': 0.6556233708130108,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Nimi': 0.4847910473578002,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Liam_Dentiri': 0.494315625213864,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Silvarte': 0.49204272129464405,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Derrin_Weller': 0.4600560823910262,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Meetra_Surik': 0.6351886676468426,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.7366170607274056,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Leontyne_Saresh': 0.625724333765507,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jace_Malcom': 0.6499678131941102,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Stantorrs': 0.6454979127998827,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander_Rans': 0.6667265605257213,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Attack_of_the_Flesh_Raiders': 0.6108276665345005,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.7597826042135829,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.667327888814614,
# ...
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Black_Talon': 0.018951009195247837,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Esseles': 0.018951009195247837,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jungle_Skinflayer': 0.014015289909767414,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Raiders': 0.01665712342150588,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Taral_V': 0.012698415935889829,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Boarding_Party': 0.012698415935889829},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Imperial_Agent': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent': 0.9496851887739858,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent_(Sith_Empire_Agent)': 0.8790972563298258,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent_Storyline': 0.6890673153567499,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Agent_(rank)': 0.36299866888201443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_agents': 0.36299866888201443},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Cipher_Nine': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent': 0.9497298618918261,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire': 0.5665372053978309,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Army': 0.5172280118194839,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Pilot_Armor_Set': 0.561452202531459,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Navy': 0.483645109864833,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent_Storyline': 0.5840065226284286,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent_(Sith_Empire_Agent)': 0.5194595203129073,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Agent_(rank)': 0.36299866888201443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Empire_Boarding_Party': 0.0020024685986426705,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Treasury_ship': 0.0020024685986426705},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Agent': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Agent': 0.9461638943356316,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Agent_(rank)': 0.4396722625195187,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Naga_Sadow': 0.656948567520592,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vitiate': 0.6762133080724677,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Acina': 0.6227171005902986,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Marka_Ragnos': 0.6071503387825075,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Hyperspace_War': 0.6229345240690091,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Corsair': 0.5773803978982066,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Civil_War': 0.639608418977618,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cold_War': 0.6388024227925109,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Galactic_War': 0.6396201187348091,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mandalorian_Wars': 0.6345758534599992,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Purge': 0.6915586169066519,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Leontyne_Saresh': 0.609158494771964,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Paran_Am-Ris': 0.6138228665764964,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cathedral_Ship': 0.6654550248074453,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Great_Sith_War': 0.6066021028456487,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dorian_Janarus': 0.6980018186865679,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander_Rans': 0.6823412250648787,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jace_Malcom': 0.6530762147565461,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Stantorrs': 0.631604106566039,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/ATC_0': 0.6467248532550636,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ezran_Outpost': 0.6073502661119734,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Emperor': 0.4981029341385699,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor’s_Hand': 0.5443820604839441,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Pureblood': 0.4651970419246604,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/303_BTC': 0.5036430671158907,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/306_BTC': 0.5122977330628512,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Chancellor': 0.5235541497389287,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pius_Dea': 0.623441476604445,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad': 0.4873422836679303,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/323_BTC': 0.5223094879914543,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Supreme_Commander': 0.5195002310197248,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Hope_(cinematic)': 0.5302477919314648,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Star_Wars:_The_Old_Republic:_Fatal_Alliance': 0.42342257093148095,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Set_the_Table': 0.5535330184525807,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor’s_Space_Station': 0.4292846649970654,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcanum': 0.4882014066066388,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/The_Emperor%27s_shuttle': 0.46068077204400226,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Envoy': 0.59742439306009,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Berooken%27s_executive_cruiser': 0.4394938003871058,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:A_Sith_Lord%27s_Rise': 0.4492016306883147,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/First_Battle_of_Bothawui': 0.3971812159915975,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Satele_Shan': 0.588628578501511,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Meetra_Surik': 0.5100379729032005,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Zym': 0.6418065523717846,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Padawan_Exposed': 0.46491180042806424,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vaiken_Spacedock': 0.12300487389040848,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gage-class_transport': 0.09031284004177537,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sun_Razer': 0.12300487389040848,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire': 0.16597957182630985,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Scourge': 0.13906336105044909,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Marr': 0.13906336105044909,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Lord': 0.48393951092447884,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Thanaton': 0.23441151482467226,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Duros': 0.47448162364386015,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cerean': 0.4414471881537865,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/A_Map_for_the_Future': 0.11790307699810376,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Rycus_Kilran': 0.2185884749566036,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Republic': 0.4812016902897789,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Founder': 0.14964225685182408,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Galactic_Senate': 0.15970030541437635,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Emperor%27s_Glory': 0.20134049666855275,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Andru': 0.22095875368066425,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Zash': 0.22095875368066425,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban': 0.19222940628061885,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Triumvirate': 0.19222940628061885,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Second_Battle_of_Bothawui': 0.18952057654619442,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Battle_of_Bothawui': 0.0003587317951005975,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Check_In': 0.21735164518918199,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Carrick_Station': 0.1445706134348267,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Citadel_Station': 0.1445706134348267,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_orbital_security_station': 0.17297623113688443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fideltin_Rusk': 0.15029743208154095,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jabiim_Escort': 0.4380918928848085,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Llanic_Station_Strike': 0.39577667503221603,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Nez_Peron_Sweep': 0.41023179678781596,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Military': 0.14641374455063283,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Navy': 0.14641374455063283,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Army': 0.14641374455063283,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kel_Dor': 0.20832083449612698,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Attack_of_the_Flesh_Raiders': 0.23398506145239928,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Grand_Master': 0.2231574878972501,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ascendant_Spear': 0.027245101123601956,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Fuliginous': 0.3909476993985786,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Javlin': 0.14146365736112682,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ebon_Hawk': 0.45105352109190755,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Revanchist': 0.16725776325112002,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Frellka': 0.11656984427355332,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Cestus': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Atroxa': 0.06200259234886912,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Massassi': 0.05610119062414537,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vette': 0.030484519874363347,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Argog': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Kory': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Terentatek': 0.05610119062414537,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_Arrival_Port': 0.06597584895738728,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Vemrin': 0.07093621582086435,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Khem_Val': 0.030484519874363347,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tuk%27ata': 0.05610119062414537,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Warrior': 0.18428782378218517,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Valley_of_the_Dark_Lords': 0.03181981899273423,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ortosin': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ffon_Althe': 0.10061234936841124,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Seferiss': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ragate': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Sith_Empire_(Jedi_Civil_War)': 0.023290937494066632,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Solence': 0.044075325955234,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Deal_with_Kendoh': 0.3820947702609016,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:The_Plan_is_Working!': 0.4489295255485357,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Telos_Security_Force': 0.03185756552450297,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Order': 0.10899726032282964,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Council': 0.06440364648050945,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Endar_Spire': 0.21917140921965178,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Battle_Organa': 0.19686496669554449,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Jedi_Cruiser': 0.10466802431391042,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Dantooine_Jedi_Enclave_Council': 0.05840953840185559,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Darth_Baras': 0.04641818131448061,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Front_Lines': 0.13352530473558355,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/K%27lor%27slug_Forager': 0.0037486867415782443,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Minst': 0.02812593894220683,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Imperial_Military_transport': 0.17371285029480743,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Moracen': 0.014392709192152187,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Arcann': 0.04455889050437045,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Family_Ties': 0.006193040264174332,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Tomb_of_Ajunta_Pall_(Explorable_Area)': 0.11122724646805698,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:Culling_the_Nekghouls': 0.08638229408166459,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Gand': 0.007688909758058027,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Silvarte': 0.007096134848839586,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Pilgrims': 0.013645713800938264,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Eclipse': 0.009792237081113986,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Enemy_Force': 0.011026249828272827,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Combat_Leadership:_Mark_II': 0.018598996543750024,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Valkorion': 0.01371081453128814,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Eternal_Fleet_Flagship': 0.01027816483361188,
#   'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mission:General_Durant': 0.0075347382228243},
#  'http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Mystic': {'http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mystic': 0.8689469891848975},
#  ...}

# %%
def get_entity_of_class(graph, type_class):
    TYPE_PREDICATE = 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'
    predicate = URIRef(TYPE_PREDICATE)
    
    object_class = URIRef(type_class)
    
    subject_list = list()
    for subject in graph.subjects(predicate, object_class):
        subject_list.append(str(subject))
    return subject_list

# %%
graph_1_class_list = get_graph_classes(graph_1)
graph_2_class_list = get_graph_classes(graph_2)

# %%
def calculate_sub_relation(subject_list_1, subject_list_2):
    sum_pair = 0.0
    for subject_1 in subject_list_1:
        total_subject = 1.0
        for subject_2 in subject_list_2:
            if subject_1 in entity_pair_dict.keys() and subject_2 in entity_pair_dict[subject_1].keys():
                total_subject *= 1 - entity_pair_dict[subject_1][subject_2]
        
        sum_pair += 1.0 - total_subject
    
    return sum_pair

# %%
class_sub_relation_list = list()

for type_class_1 in tqdm(graph_1_class_list, desc='type 1'):
    subject_list_1 = get_entity_of_class(graph_1, type_class_1)
    
    total_subjects_1 = len(subject_list_1)
    if total_subjects_1 == 0:
        continue
    for type_class_2 in tqdm(graph_2_class_list, desc='type 2', leave=False):
        subject_list_2 = get_entity_of_class(graph_2, type_class_2)
        
        total_sum_relation = calculate_sub_relation(subject_list_1, subject_list_2)
        
        class_sub_relation_list.append({
            'class1': type_class_1,
            'class2': type_class_2,
            'subclass': total_sum_relation / total_subjects_1
        })
# Out:
# type 1:   0%|          | 0/181 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]
# type 2:   0%|          | 0/283 [00:00<?, ?it/s]

# %%
sub_relation_df = pd.DataFrame(class_sub_relation_list)

# %%
pd.set_option('display.max_colwidth', None)

# %%
sub_relation_df[sub_relation_df['subclass'] > 0.5].sort_values('subclass', ascending=False)
# Out:
#                                                                                     class1  \
# 43834  http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_species_xindi
# 31486              http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/novel_nav
# 42523           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_film
# 43651  http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_species_xindi
# 12286           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_year
# 15317             http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/decade_nav
# 40358                   http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/omid
# 43697  http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_species_xindi
# 42453           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_film
# 18795           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/timeline_nav
# 15895   http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/prime_disambiguation
# 17615     http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_government
# 17798     http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_government
# 35488           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_rank
# 43585  http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_species_xindi
# 43868    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_comic_strip
# 43909    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_comic_strip
# 23702    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/starfleet_personnel
# 42719           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_film
# 31435              http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/novel_nav
# 11154         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_series
#
#                                                                              class2  \
# 43834       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/battle_data
# 31486    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fanfic_episode
# 42523    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fanfic_episode
# 43651         http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/character
# 12286           http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/yearbox
# 15317          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/timeline
# 40358               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ds9
# 43697               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ent
# 42453   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fanfilm_episode
# 18795           http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/yearbox
# 15895  http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/starship-sidebar
# 17615         http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/character
# 17798       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/battle_data
# 35488       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/superimpose
# 43585   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fanfilm_episode
# 43868   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fanfilm_episode
# 43909          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/phase_ii
# 23702          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/pagename
# 42719    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/starship-class
# 31435     http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/rpg-challenge
# 11154           http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/yearbox
#
#        subclass
# 43834  0.998141
# 31486  0.992436
# 42523  0.906800
# 43651  0.883932
# 12286  0.877747
# 15317  0.876883
# 40358  0.876228
# 43697  0.876228
# 42453  0.837127
# 18795  0.793217
# 15895  0.784000
# 17615  0.780030
# 17798  0.757967
# 35488  0.755946
# 43585  0.734200
# 43868  0.682980
# 43909  0.679230
# 23702  0.638114
# 42719  0.637262
# 31435  0.599437
# 11154  0.514624

# %%
pd.set_option('display.max_colwidth', None)

# %%
class_list = list()

for class_1, class_2_dict in class_sem_prob_dict.items():
    for class_2 in class_2_dict:
        class_list.append({'class_1': class_1,
                          'class_2': class_2,
                          'sim': class_2_dict[class_2]})

# %%
class_df = pd.DataFrame(class_list)

# %%
one_one_class_df = class_df.sort_values('sim', ascending=False).drop_duplicates('class_1').drop_duplicates('class_2')

# %%
one_one_class_df[one_one_class_df['sim'] > 0.5]
# Out:
#                                                                                       class_1  \
# 0                     http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/wikipedia
# 1692                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/%27
# 2539                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/tas
# 846                           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/m
# 1410                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/tos
# 282                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/voy
# 4513                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/mb
# 564                           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/w
# 4231                          http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/e
# 3949            http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_species
# 2257                       http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/film
# 1693                      http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/class
# 3667                      http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/mbeta
# 1975                      http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/clear
# 3385                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/dis
# 2821                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/ds9
# 1128                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/tng
# 3103                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/ent
# 4795                 http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/compacttoc
# 5359                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/uss
# 5641                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/iss
# 5077                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/ss
# 5923                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/iks
# 24470             http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_novel
# 46598             http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_actor
# 46235    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_starship_class
# 16828    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_reference_book
# 24580                http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/real_world
# 48402         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_videogame
# 17501                   http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/stowiki
# 31823                    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/aquote
# 37754               http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/mbeta-title
# 37791                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/s
# 36688              http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_rank
# 38125           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/stub-production
# 19588                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/d
# 29550                      http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/stng
# 31184                    http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/humans
# 42894                       http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/ste
# 32007                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/y
# 19971      http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/prime_disambiguation
# 21252           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_element
# 25095         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/ep_disambiguation
# 23075           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_station
# 22314              http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/timeline_nav
# 9046           http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_starship
# 6612                         http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/st
# 6485            http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_episode
# 48574  http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/non_canon_character_page
# 49508                http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/merge_with
# 40133                       http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/exp
# 15238                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/bd
# 39184            http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_planet
# 13860                     http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/audio
# 9968                        http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/nth
# 27609                http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/day_footer
# 18259               http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/broken_link
# 43472                 http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/comic_nav
# 23402       http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/sidebar_star_system
# 37126                   http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/class/aolchat
#
#                                                                                                   class_2  \
# 0                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/wikipedia
# 1692                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/%27
# 2539                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/tas
# 846                                         http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/m
# 1410                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/tos
# 282                                       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/voy
# 4513                                       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/mb
# 564                                         http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/w
# 4231                                        http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/e
# 3949                          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/sidebar_species
# 2257                                     http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/film
# 1693                                    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/class
# 3667                                    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/mbeta
# 1975                                    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/clear
# 3385                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/dis
# 2821                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ds9
# 1128                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/tng
# 3103                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ent
# 4795                               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/compacttoc
# 5359                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/uss
# 5641                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/iss
# 5077                                       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ss
# 5923                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/iks
# 24470                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/novel
# 46598                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/actor
# 46235                          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/starship-class
# 16828                          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/reference-book
# 24580                               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/realworld
# 48402                              http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/video_game
# 17501                                 http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/stowiki
# 31823                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/quote
# 37754                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/tl
# 37791                                 http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/origins
# 36688                     http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/starfleet_rank_eras
# 38125                                    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/stub
# 19588                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/cadre
# 29550                                       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/g
# 31184                                      http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ma
# 42894                               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/existence
# 32007                                    http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/copy
# 19971                                http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/disambig
# 21252         http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/starfleet_marine_corps_elements
# 25095                             http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ep_disambig
# 23075  http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/federation_space_stations_and_outposts
# 22314                                http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/timeline
# 9046                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/larson_class_starships
# 6612                           http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/battlestarwiki
# 6485                        http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/bouteina_episodes
# 48574                               http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/character
# 49508                                   http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/merge
# 40133                                       http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/p
# 15238                                     http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ibd
# 39184                           http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/mirror-planet
# 13860                        http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fan_audio_series
# 9968                          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/titleofthemonth
# 27609                http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/shadowstarofficersfooter
# 18259              http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/broken_bow_class_starships
# 43472                          http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/fan_comic_info
# 23402                 http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/ships_of_the_star_fleet
# 37126                                     http://dbkwik.webdatacommons.org/stexpanded.wikia.com/class/aos
#
#             sim
# 0      0.900000
# 1692   0.900000
# 2539   0.900000
# 846    0.900000
# 1410   0.900000
# 282    0.900000
# 4513   0.900000
# 564    0.900000
# 4231   0.900000
# 3949   0.900000
# 2257   0.900000
# 1693   0.900000
# 3667   0.900000
# 1975   0.900000
# 3385   0.900000
# 2821   0.900000
# 1128   0.900000
# 3103   0.900000
# 4795   0.900000
# 5359   0.800000
# 5641   0.800000
# 5077   0.800000
# 5923   0.800000
# 24470  0.600000
# 46598  0.600000
# 46235  0.577778
# 16828  0.577778
# 24580  0.568421
# 48402  0.568421
# 17501  0.560000
# 31823  0.545455
# 37754  0.540000
# 37791  0.540000
# 36688  0.540000
# 38125  0.540000
# 19588  0.540000
# 29550  0.540000
# 31184  0.540000
# 42894  0.540000
# 32007  0.540000
# 19971  0.540000
# 21252  0.540000
# 25095  0.540000
# 23075  0.540000
# 22314  0.540000
# 9046   0.540000
# 6612   0.540000
# 6485   0.540000
# 48574  0.540000
# 49508  0.540000
# 40133  0.540000
# 15238  0.540000
# 39184  0.540000
# 13860  0.540000
# 9968   0.540000
# 27609  0.513000
# 18259  0.513000
# 43472  0.513000
# 23402  0.513000
# 37126  0.513000

# %%
len(one_one_class_df[one_one_class_df['sim'] > 0.5])
# Out:
# 60

# %%
def get_graph_classes(graph):
    query = """
        select * {?s a rdfs:Resource.}
        """
    class_list = list()
    
    for res in graph.query(query):
        class_list.append(res[0])
    return class_list
