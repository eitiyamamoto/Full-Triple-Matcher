# %%
from rdflib import Graph
import re
import pandas as pd
from rdflib import Graph, URIRef, Namespace, Literal
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm

# %%
graph = Graph()

graph.parse(
    '/Users/yamamotobikutorueiichi/codes/custom_paris/knowledgegraph-alignments-4/starwars-swtor/BaselineAltLabel/systemAlignment.rdf')

map_list = list()

for subj, pred, obj in graph.triples(
    (None, None, URIRef('http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell'))):
    cell_dict = dict()
    for cell_subj, cell_pred, cell_obj in graph.triples((subj, None, None)):
        cell_dict[str(cell_pred)] = str(cell_obj)
    map_list.append(cell_dict)

# %%
pd.set_option('display.max_colwidth', None)

# %%
map_df = pd.DataFrame(map_list)

# %%
generated_df = map_df.rename(columns={
    'http://knowledgeweb.semanticweb.org/heterogeneity/alignmententity1': 'e1',
    'http://knowledgeweb.semanticweb.org/heterogeneity/alignmententity2': 'e2',
    'http://knowledgeweb.semanticweb.org/heterogeneity/alignmentmeasure': 'sim'
})

# %%
generated_df
# Out:
#                       http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 0     http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 1     http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 2     http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 3     http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 4     http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# ...                                                               ...
# 2660  http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 2661  http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 2662  http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 2663  http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
# 2664  http://knowledgeweb.semanticweb.org/heterogeneity/alignmentCell
#
#                                                                                                        e1  \
# 0                                http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Aric_Jorgan
# 1                                http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Havoc_Squad
# 2     http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Republic_Strategic_Information_Service
# 3                                   http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Lantikus
# 4                                http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Numen_Brock
# ...                                                                                                   ...
# 2660                                  http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Bahlea
# 2661                                    http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Ryen
# 2662                             http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Indignation
# 2663                               http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Mercenary
# 2664                   http://dbkwik.webdatacommons.org/starwars.wikia.com/resource/Korriban_Arrival_Port
#
#                                                                                                     e2  \
# 0                                http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Aric_Jorgan
# 1                                http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Havoc_Squad
# 2     http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Republic_Strategic_Information_Service
# 3                                   http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Lantikus
# 4                                http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Numen_Brock
# ...                                                                                                ...
# 2660                                  http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Bahlea
# 2661                                    http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Ryen
# 2662                             http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Indignation
# 2663                               http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Mercenary
# 2664                   http://dbkwik.webdatacommons.org/swtor.wikia.com/resource/Korriban_Arrival_Port
#
#      http://knowledgeweb.semanticweb.org/heterogeneity/alignmentrelation  sim
# 0                                                                      =  1.0
# 1                                                                      =  1.0
# 2                                                                      =  1.0
# 3                                                                      =  1.0
# 4                                                                      =  1.0
# ...                                                                  ...  ...
# 2660                                                                   =  1.0
# 2661                                                                   =  1.0
# 2662                                                                   =  1.0
# 2663                                                                   =  1.0
# 2664                                                                   =  1.0
#
# [2665 rows x 5 columns]

# %%
generated_df.to_csv('/Users/yamamotobikutorueiichi/codes/custom_paris/knowledgegraph-alignments-4/starwars-swtor/BaselineAltLabel/systemAlignment.csv')

# %%
graph = Graph()

graph.parse('/Users/yamamotobikutorueiichi/codes/i-align/i-align/LargeData/600K/mapping.ttl')

map_list = list()

for subj, pred, obj in graph.triples((None, URIRef('http://www.w3.org/2002/07/owl#sameAs'), None)):
    map_list.append({
        'e2': str(subj),
        'e1': str(obj)
    })

# %%
match_df = pd.DataFrame(map_list)

# %%
#match_df.to_csv('//Users/yamamotobikutorueiichi/codes/i-align/i-align/LargeData/600K/mapping.csv')

# %%
match_df = pd.read_csv('/Users/yamamotobikutorueiichi/codes/custom_paris/mcu-mdb-gold.csv')

# %%
match_df
# Out:
#       Unnamed: 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 0              0  http://knowledgeweb.semanticweb.org/heterogene...
# 1              1  http://knowledgeweb.semanticweb.org/heterogene...
# 2              2  http://knowledgeweb.semanticweb.org/heterogene...
# 3              3  http://knowledgeweb.semanticweb.org/heterogene...
# 4              4  http://knowledgeweb.semanticweb.org/heterogene...
# ...          ...                                                ...
# 1662        1662  http://knowledgeweb.semanticweb.org/heterogene...
# 1663        1663  http://knowledgeweb.semanticweb.org/heterogene...
# 1664        1664  http://knowledgeweb.semanticweb.org/heterogene...
# 1665        1665  http://knowledgeweb.semanticweb.org/heterogene...
# 1666        1666  http://knowledgeweb.semanticweb.org/heterogene...
#
#                                                      e1  \
# 0     http://dbkwik.webdatacommons.org/marvelcinemat...
# 1     http://dbkwik.webdatacommons.org/marvelcinemat...
# 2     http://dbkwik.webdatacommons.org/marvelcinemat...
# 3     http://dbkwik.webdatacommons.org/marvelcinemat...
# 4     http://dbkwik.webdatacommons.org/marvelcinemat...
# ...                                                 ...
# 1662  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1663  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1664  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1665  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1666  http://dbkwik.webdatacommons.org/marvelcinemat...
#
#                                                      e2  \
# 0     http://dbkwik.webdatacommons.org/marvel.wikia....
# 1     http://dbkwik.webdatacommons.org/marvel.wikia....
# 2     http://dbkwik.webdatacommons.org/marvel.wikia....
# 3     http://dbkwik.webdatacommons.org/marvel.wikia....
# 4     http://dbkwik.webdatacommons.org/marvel.wikia....
# ...                                                 ...
# 1662  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1663  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1664  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1665  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1666  http://dbkwik.webdatacommons.org/marvel.wikia....
#
#      http://knowledgeweb.semanticweb.org/heterogeneity/alignmentrelation  sim
# 0                                                     =                   1.0
# 1                                                     =                   1.0
# 2                                                     =                   1.0
# 3                                                     =                   1.0
# 4                                                     =                   1.0
# ...                                                 ...                   ...
# 1662                                                  =                   1.0
# 1663                                                  =                   1.0
# 1664                                                  =                   1.0
# 1665                                                  =                   1.0
# 1666                                                  =                   1.0
#
# [1667 rows x 6 columns]

# %%
generated_df = pd.read_csv(
    '/Users/yamamotobikutorueiichi/codes/custom_paris/knowledgegraph-alignments-4/marvelcinematicuniverse-marvel/BaselineAltLabel/systemAlignment.csv')

#generated_df = pd.read_csv(
#    '/Users/yamamotobikutorueiichi/codes/paris/dwy-600k/9_eqv_full.tsv', sep='\t', names=['e1', 'e2', 'sim'])

# %%
generated_df
# Out:
#       Unnamed: 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 0              0  http://knowledgeweb.semanticweb.org/heterogene...
# 1              1  http://knowledgeweb.semanticweb.org/heterogene...
# 2              2  http://knowledgeweb.semanticweb.org/heterogene...
# 3              3  http://knowledgeweb.semanticweb.org/heterogene...
# 4              4  http://knowledgeweb.semanticweb.org/heterogene...
# ...          ...                                                ...
# 2569        2569  http://knowledgeweb.semanticweb.org/heterogene...
# 2570        2570  http://knowledgeweb.semanticweb.org/heterogene...
# 2571        2571  http://knowledgeweb.semanticweb.org/heterogene...
# 2572        2572  http://knowledgeweb.semanticweb.org/heterogene...
# 2573        2573  http://knowledgeweb.semanticweb.org/heterogene...
#
#                                                      e1  \
# 0     http://dbkwik.webdatacommons.org/marvelcinemat...
# 1     http://dbkwik.webdatacommons.org/marvelcinemat...
# 2     http://dbkwik.webdatacommons.org/marvelcinemat...
# 3     http://dbkwik.webdatacommons.org/marvelcinemat...
# 4     http://dbkwik.webdatacommons.org/marvelcinemat...
# ...                                                 ...
# 2569  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2570  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2571  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2572  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2573  http://dbkwik.webdatacommons.org/marvelcinemat...
#
#                                                      e2  \
# 0     http://dbkwik.webdatacommons.org/marvel.wikia....
# 1     http://dbkwik.webdatacommons.org/marvel.wikia....
# 2     http://dbkwik.webdatacommons.org/marvel.wikia....
# 3     http://dbkwik.webdatacommons.org/marvel.wikia....
# 4     http://dbkwik.webdatacommons.org/marvel.wikia....
# ...                                                 ...
# 2569  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2570  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2571  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2572  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2573  http://dbkwik.webdatacommons.org/marvel.wikia....
#
#      http://knowledgeweb.semanticweb.org/heterogeneity/alignmentrelation  sim
# 0                                                     =                   1.0
# 1                                                     =                   1.0
# 2                                                     =                   1.0
# 3                                                     =                   1.0
# 4                                                     =                   1.0
# ...                                                 ...                   ...
# 2569                                                  =                   1.0
# 2570                                                  =                   1.0
# 2571                                                  =                   1.0
# 2572                                                  =                   1.0
# 2573                                                  =                   1.0
#
# [2574 rows x 6 columns]

# %%
generated_df['e1'] = generated_df['e1'].str.replace(
    'dbp:resource/', 'http://dbpedia.org/resource/')

# %%
generated_df['e2'] = generated_df['e2'].str.replace(
    'y2:', 'http://yago-knowledge.org/resource/')

# %%
generated_df
# Out:
#       Unnamed: 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 0              0  http://knowledgeweb.semanticweb.org/heterogene...
# 1              1  http://knowledgeweb.semanticweb.org/heterogene...
# 2              2  http://knowledgeweb.semanticweb.org/heterogene...
# 3              3  http://knowledgeweb.semanticweb.org/heterogene...
# 4              4  http://knowledgeweb.semanticweb.org/heterogene...
# ...          ...                                                ...
# 2569        2569  http://knowledgeweb.semanticweb.org/heterogene...
# 2570        2570  http://knowledgeweb.semanticweb.org/heterogene...
# 2571        2571  http://knowledgeweb.semanticweb.org/heterogene...
# 2572        2572  http://knowledgeweb.semanticweb.org/heterogene...
# 2573        2573  http://knowledgeweb.semanticweb.org/heterogene...
#
#                                                      e1  \
# 0     http://dbkwik.webdatacommons.org/marvelcinemat...
# 1     http://dbkwik.webdatacommons.org/marvelcinemat...
# 2     http://dbkwik.webdatacommons.org/marvelcinemat...
# 3     http://dbkwik.webdatacommons.org/marvelcinemat...
# 4     http://dbkwik.webdatacommons.org/marvelcinemat...
# ...                                                 ...
# 2569  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2570  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2571  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2572  http://dbkwik.webdatacommons.org/marvelcinemat...
# 2573  http://dbkwik.webdatacommons.org/marvelcinemat...
#
#                                                      e2  \
# 0     http://dbkwik.webdatacommons.org/marvel.wikia....
# 1     http://dbkwik.webdatacommons.org/marvel.wikia....
# 2     http://dbkwik.webdatacommons.org/marvel.wikia....
# 3     http://dbkwik.webdatacommons.org/marvel.wikia....
# 4     http://dbkwik.webdatacommons.org/marvel.wikia....
# ...                                                 ...
# 2569  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2570  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2571  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2572  http://dbkwik.webdatacommons.org/marvel.wikia....
# 2573  http://dbkwik.webdatacommons.org/marvel.wikia....
#
#      http://knowledgeweb.semanticweb.org/heterogeneity/alignmentrelation  sim
# 0                                                     =                   1.0
# 1                                                     =                   1.0
# 2                                                     =                   1.0
# 3                                                     =                   1.0
# 4                                                     =                   1.0
# ...                                                 ...                   ...
# 2569                                                  =                   1.0
# 2570                                                  =                   1.0
# 2571                                                  =                   1.0
# 2572                                                  =                   1.0
# 2573                                                  =                   1.0
#
# [2574 rows x 6 columns]

# %%
match_df
# Out:
#       Unnamed: 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type  \
# 0              0  http://knowledgeweb.semanticweb.org/heterogene...
# 1              1  http://knowledgeweb.semanticweb.org/heterogene...
# 2              2  http://knowledgeweb.semanticweb.org/heterogene...
# 3              3  http://knowledgeweb.semanticweb.org/heterogene...
# 4              4  http://knowledgeweb.semanticweb.org/heterogene...
# ...          ...                                                ...
# 1662        1662  http://knowledgeweb.semanticweb.org/heterogene...
# 1663        1663  http://knowledgeweb.semanticweb.org/heterogene...
# 1664        1664  http://knowledgeweb.semanticweb.org/heterogene...
# 1665        1665  http://knowledgeweb.semanticweb.org/heterogene...
# 1666        1666  http://knowledgeweb.semanticweb.org/heterogene...
#
#                                                      e1  \
# 0     http://dbkwik.webdatacommons.org/marvelcinemat...
# 1     http://dbkwik.webdatacommons.org/marvelcinemat...
# 2     http://dbkwik.webdatacommons.org/marvelcinemat...
# 3     http://dbkwik.webdatacommons.org/marvelcinemat...
# 4     http://dbkwik.webdatacommons.org/marvelcinemat...
# ...                                                 ...
# 1662  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1663  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1664  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1665  http://dbkwik.webdatacommons.org/marvelcinemat...
# 1666  http://dbkwik.webdatacommons.org/marvelcinemat...
#
#                                                      e2  \
# 0     http://dbkwik.webdatacommons.org/marvel.wikia....
# 1     http://dbkwik.webdatacommons.org/marvel.wikia....
# 2     http://dbkwik.webdatacommons.org/marvel.wikia....
# 3     http://dbkwik.webdatacommons.org/marvel.wikia....
# 4     http://dbkwik.webdatacommons.org/marvel.wikia....
# ...                                                 ...
# 1662  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1663  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1664  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1665  http://dbkwik.webdatacommons.org/marvel.wikia....
# 1666  http://dbkwik.webdatacommons.org/marvel.wikia....
#
#      http://knowledgeweb.semanticweb.org/heterogeneity/alignmentrelation  sim
# 0                                                     =                   1.0
# 1                                                     =                   1.0
# 2                                                     =                   1.0
# 3                                                     =                   1.0
# 4                                                     =                   1.0
# ...                                                 ...                   ...
# 1662                                                  =                   1.0
# 1663                                                  =                   1.0
# 1664                                                  =                   1.0
# 1665                                                  =                   1.0
# 1666                                                  =                   1.0
#
# [1667 rows x 6 columns]

# %%
graph = Graph()
graph.parse("/Users/yamamotobikutorueiichi/codes/i-align/i-align/LargeData/300K/wd.ttl")
# Out:
# <Graph identifier=N1fa867f0170e47fa93b489b8fccdaefa (<class 'rdflib.graph.Graph'>)>

# %%
for _, row in tqdm(match_df.iterrows()):
    entity = row['e2']
    if (URIRef(entity), URIRef('http://www.w3.org/2000/01/rdf-schema#label'), None) not in graph:
        print(entity)
# Out:
# 0it [00:00, ?it/s]
# http://www.wikidata.org/entity/Q2499878
# http://www.wikidata.org/entity/Q16926586
# http://www.wikidata.org/entity/Q654220
# http://www.wikidata.org/entity/Q5971015
# http://www.wikidata.org/entity/Q7072879
# http://www.wikidata.org/entity/Q683531
# http://www.wikidata.org/entity/Q4646757
# http://www.wikidata.org/entity/Q5427565
# http://www.wikidata.org/entity/Q2704276
# http://www.wikidata.org/entity/Q1951540
# http://www.wikidata.org/entity/Q6926934
# http://www.wikidata.org/entity/Q1198564
# http://www.wikidata.org/entity/Q7692108
# http://www.wikidata.org/entity/Q2079101
# http://www.wikidata.org/entity/Q287009
# http://www.wikidata.org/entity/Q7619899
# http://www.wikidata.org/entity/Q5204181
# http://www.wikidata.org/entity/Q6941390
# http://www.wikidata.org/entity/Q6863421

# %%
def get_top_n(dictionary, n, reverse=True):
    sorted_elements = sorted(dictionary.items(), key=lambda x: x[1], reverse=reverse)
    if len(sorted_elements) < n:
        return sorted_elements
    n_sim = sorted_elements[n-1][1]
    
    top_n_list = list()
    for element in sorted_elements:
        e2, sim = element
        if (reverse and sim < n_sim) or (not reverse and sim > n_sim):
            return top_n_list
            
        top_n_list.append(element)
    return top_n_list

# %%
# Group the DataFrame by 'e1'
grouped_df = generated_df.groupby('e1')

# %%
elem_dict = dict()
for e1, group_indices in tqdm(grouped_df.groups.items()):
    # Access the group corresponding to 'e1'
    e1_group = generated_df.iloc[group_indices]
    e1_dict = dict(zip(e1_group['e2'], e1_group['sim']))
    elem_dict[e1] = e1_dict
# Out:
#   0%|          | 0/2489 [00:00<?, ?it/s]

# %%
hit_at_one_dict = dict()

for e1, e1_dict in elem_dict.items():
    top_list = get_top_n(e1_dict, 1)
    for e2, sim in top_list:
        hit_at_one_dict[e1] = top_list

# %%
hits = 0
for _, row in match_df.iterrows():
    e1 = row['e1']
    if e1 not in hit_at_one_dict.keys():
        continue
    top_list = hit_at_one_dict[e1]
    e2 = row['e2']
    for top_e2, sim in top_list:
        if e2 == top_e2:
            hits += 1
            continue

# %%
hits
# Out:
# 1128

# %%
hits / len(match_df)
# Out:
# 0.6766646670665867

# %%
hit_at_ten_dict = dict()

for e1, e1_dict in elem_dict.items():
    top_list = get_top_n(e1_dict, 10)
    for e2, sim in top_list:
        hit_at_ten_dict[e1] = top_list

# %%
hits = 0
for _, row in match_df.iterrows():
    e1 = row['e1']
    if e1 not in hit_at_ten_dict.keys():
        continue
    top_list = hit_at_ten_dict[e1]
    e2 = row['e2']
    for top_e2, sim in top_list:
        if e2 == top_e2:
            hits += 1
            continue

# %%
hits
# Out:
# 1128

# %%
hits / len(match_df)
# Out:
# 0.6766646670665867
