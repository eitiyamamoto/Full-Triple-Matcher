# %%
from rdflib import Graph, URIRef, Namespace
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from tqdm import tqdm
import pandas as pd

# %%
#rdflib_dbpedia_graph = Graph("SPARQLStore")
#rdflib_dbpedia_graph.open("http://localhost:9999/bigdata/sparql")

graph = Graph()
graph.parse("/Users/yamamotobikutorueiichi/codes/i-align/i-align/DWY-NB/DW-NB/kg1.ttl")
# Out:
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0609'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0698'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0206'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0371'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0523'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0322'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0100-07-13'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0262'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0490'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0445'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0360'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0520'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0384'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0785'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0323'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0058-01-30'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0676'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0520'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0043-12-07'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-2333-10-03'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0441'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0441'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0412'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0341'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0365'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0010-08-01'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0851'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0086-01-13'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0753'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0015-05-24'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0270'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0508'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0285'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0330'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0087-03-29'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#date, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0019-09-21'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0660'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x10785a670>
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/opt/homebrew/Caskroom/miniforge/base/envs/berkeley/lib/python3.9/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0195'
# <Graph identifier=N8cec9d23cef2446799b5044954de36b0 (<class 'rdflib.graph.Graph'>)>

# %%
query = """
SELECT DISTINCT ?p
WHERE {
  # ?s ?p ?o.
}"""
pred_res_list = graph.query(query)

# %%
count_total_query = """
SELECT (COUNT(*) AS ?totalCount)
WHERE {
    # ?s <:pred> ?o
}
"""

count_total_obj_query = """
SELECT (COUNT(DISTINCT ?o) AS ?totalCount)
WHERE {
    # ?s <:pred> ?o
}
"""

inv_func_dict = dict()
for pred_res in tqdm(pred_res_list):
    query_pred = pred_res[0]

    try:
        replaced_count_total_query = count_total_query.replace(':pred', str(query_pred))
        count_res = graph.query(replaced_count_total_query)
        total_count = 0
        for res in count_res:
            total_count = res.totalCount

        replaced_count_total_obj_query = count_total_obj_query.replace(':pred', str(query_pred))
        count_res = graph.query(replaced_count_total_obj_query)
        total_obj = 0
        for res in count_res:
            total_obj = res.totalCount
        
        inv_func_dict[str(query_pred)] = float(total_obj)/float(total_count)
    except Exception as e:
        print(e)
        print("exception raised: " + str(query_pred))
# Out:
# 100%|█████████████████████████████████████████| 545/545 [00:07<00:00, 77.54it/s]

# %%
inv_func_list = list()
for key, value in inv_func_dict.items():
    inv_func_list.append({
        'predicate': key,
        'inverse_functionality': value
    })

# %%
inv_func_df = pd.DataFrame(inv_func_list)

# %%
inv_func_df
# Out:
#                                              predicate  inverse_functionality
# 0     http://dbpedia.org/ontology/activeYearsStartYear               0.135437
# 1              http://dbpedia.org/ontology/musicalBand               0.270300
# 2                   http://www.wikidata.org/entity/P26               0.932704
# 3                  http://dbpedia.org/ontology/runtime               0.226362
# 4                  http://www.wikidata.org/entity/P264               0.023195
# ..                                                 ...                    ...
# 540      http://dbpedia.org/ontology/otherServingLines               1.000000
# 541          http://dbpedia.org/ontology/associatedAct               1.000000
# 542         http://dbpedia.org/ontology/bodyDiscovered               1.000000
# 543  http://dbpedia.org/ontology/supplementalDraftR...               1.000000
# 544          http://dbpedia.org/ontology/numberOfFilms               1.000000
#
# [545 rows x 2 columns]

# %%
inv_func_df[inv_func_df['inverse_functionality'] > 0.5]
# Out:
#                                              predicate  inverse_functionality
# 2                   http://www.wikidata.org/entity/P26               0.932704
# 5           http://www.w3.org/2000/01/rdf-schema#label               0.961267
# 6                   http://dbpedia.org/ontology/parent               0.599419
# 8                  http://www.wikidata.org/entity/P570               0.848890
# 10             http://dbpedia.org/ontology/notableWork               0.960145
# ..                                                 ...                    ...
# 540      http://dbpedia.org/ontology/otherServingLines               1.000000
# 541          http://dbpedia.org/ontology/associatedAct               1.000000
# 542         http://dbpedia.org/ontology/bodyDiscovered               1.000000
# 543  http://dbpedia.org/ontology/supplementalDraftR...               1.000000
# 544          http://dbpedia.org/ontology/numberOfFilms               1.000000
#
# [426 rows x 2 columns]

# %%
query = """
SELECT DISTINCT ?p
WHERE {
  # ?s ?p ?o.
}"""
pred_res_list = graph.query(query)

# %%
count_total_query = """
SELECT (COUNT(*) AS ?totalCount)
WHERE {
    # ?s <:pred> ?o
}
"""

count_total_subj_query = """
SELECT (COUNT(DISTINCT ?s) AS ?totalCount)
WHERE {
    # ?s <:pred> ?o
}
"""

func_dict = dict()
for pred_res in tqdm(pred_res_list):
    query_pred = pred_res[0]

    try:
        replaced_count_total_query = count_total_query.replace(':pred', str(query_pred))
        count_res = graph.query(replaced_count_total_query)
        total_count = 0
        for res in count_res:
            total_count = res.totalCount

        replaced_count_total_subj_query = count_total_subj_query.replace(':pred', str(query_pred))
        count_res = graph.query(replaced_count_total_subj_query)
        total_obj = 0
        for res in count_res:
            total_obj = res.totalCount
        
        func_dict[str(query_pred)] = float(total_obj)/float(total_count)
    except Exception as e:
        print(e)
        print("exception raised: " + str(query_pred))
# Out:
# 100%|█████████████████████████████████████████| 545/545 [00:07<00:00, 72.53it/s]

# %%
func_list = list()
for key, value in func_dict.items():
    func_list.append({
        'predicate': key,
        'functionality': value
    })

# %%
func_df = pd.DataFrame(func_list)

# %%
func_df
# Out:
#                                              predicate  functionality
# 0    http://dbkwik.webdatacommons.org/ontology/wiki...       0.035206
# 1    http://dbkwik.webdatacommons.org/starwars.wiki...       0.977656
# 2         http://www.w3.org/2004/02/skos/core#altLabel       0.720581
# 3    http://dbkwik.webdatacommons.org/starwars.wiki...       0.098430
# 4                     http://purl.org/dc/terms/subject       0.485668
# ..                                                 ...            ...
# 710  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 711  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 712  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 713  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 714  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
#
# [715 rows x 2 columns]

# %%
func_df[func_df['functionality'] > 0.5]
# Out:
#                                              predicate  functionality
# 1    http://dbkwik.webdatacommons.org/starwars.wiki...       0.977656
# 2         http://www.w3.org/2004/02/skos/core#altLabel       0.720581
# 6                  http://xmlns.com/foaf/0.1/thumbnail       1.000000
# 7                  http://xmlns.com/foaf/0.1/depiction       0.610629
# 11          http://www.w3.org/2000/01/rdf-schema#label       0.999988
# ..                                                 ...            ...
# 710  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 711  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 712  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 713  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 714  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
#
# [583 rows x 2 columns]

# %%
inversability_df = pd.merge(func_df, inv_func_df, on='predicate')
inversability_df['inversability'] = inversability_df['inverse_functionality'] * inversability_df['functionality']

# %%
inversability_df
# Out:
#                                              predicate  functionality  \
# 0    http://dbkwik.webdatacommons.org/ontology/wiki...       0.035206
# 1    http://dbkwik.webdatacommons.org/starwars.wiki...       0.977656
# 2         http://www.w3.org/2004/02/skos/core#altLabel       0.720581
# 3    http://dbkwik.webdatacommons.org/starwars.wiki...       0.098430
# 4                     http://purl.org/dc/terms/subject       0.485668
# ..                                                 ...            ...
# 710  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 711  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 712  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 713  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 714  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
#
#      inverse_functionality  inversability
# 0                 0.062096       0.002186
# 1                 0.069264       0.067716
# 2                 1.000000       0.720581
# 3                 0.281726       0.027730
# 4                 0.036142       0.017553
# ..                     ...            ...
# 710               1.000000       1.000000
# 711               1.000000       1.000000
# 712               1.000000       1.000000
# 713               1.000000       1.000000
# 714               1.000000       1.000000
#
# [715 rows x 4 columns]

# %%
inversability_df[inversability_df['inverse_functionality'] > 0.5]
# Out:
#                                              predicate  functionality  \
# 2         http://www.w3.org/2004/02/skos/core#altLabel       0.720581
# 5    http://dbkwik.webdatacommons.org/ontology/wiki...       0.466285
# 6                  http://xmlns.com/foaf/0.1/thumbnail       1.000000
# 10   http://dbkwik.webdatacommons.org/ontology/wiki...       0.194282
# 11          http://www.w3.org/2000/01/rdf-schema#label       0.999988
# ..                                                 ...            ...
# 710  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 711  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 712  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 713  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
# 714  http://dbkwik.webdatacommons.org/starwars.wiki...       1.000000
#
#      inverse_functionality  inversability
# 2                 1.000000       0.720581
# 5                 0.746123       0.347906
# 6                 1.000000       1.000000
# 10                0.954772       0.185495
# 11                0.992669       0.992658
# ..                     ...            ...
# 710               1.000000       1.000000
# 711               1.000000       1.000000
# 712               1.000000       1.000000
# 713               1.000000       1.000000
# 714               1.000000       1.000000
#
# [407 rows x 4 columns]

# %%
inversability_df.to_csv('')
